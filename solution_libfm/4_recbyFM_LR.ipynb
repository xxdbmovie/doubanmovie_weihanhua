# %%
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
import pandas as pd
import pickle as pkl

# %%
LIBFM_PATH = 'D:\software\libfm-1.40.windows\libfm.exe'
model_path = '../dataset/recsysmode.fm'

# %%
# !$LIBFM_PATH
# Out:
# ----------------------------------------------------------------------------
# libFM
#   Version: 1.40
#   Author:  Steffen Rendle, steffen.rendle@uni-konstanz.de
#   WWW:     http://www.libfm.org/
#   License: Free for academic use. See license.txt.
# ----------------------------------------------------------------------------
# -cache_size     cache size for data storage (only applicable if data is
#                 in binary format), default=infty
# -dim            'k0,k1,k2': k0=use bias, k1=use 1-way interactions,
#                 k2=dim of 2-way interactions; default=1,1,8
# -help           this screen
# -init_stdev     stdev for initialization of 2-way factors; default=0.1
# -iter           number of iterations; default=100
# -learn_rate     learn_rate for SGD; default=0.1
# -meta           filename for meta information about data set
# -method         learning method (SGD, SGDA, ALS, MCMC); default=MCMC
# -out            filename for output
# -regular        'r0,r1,r2' for SGD and ALS: r0=bias regularization,
#                 r1=1-way regularization, r2=2-way regularization
# -relation       BS: filenames for the relations, default=''
# -rlog           write measurements within iterations to a file;
#                 default=''
# -task           r=regression, c=binary classification [MANDATORY]
# -test           filename for test data [MANDATORY]
# -train          filename for training data [MANDATORY]
# -validation     filename for validation data (only for SGDA)
# -verbosity      how much infos to print; default=0

# %% [markdown]
# ## FM模型训练和预测，使用libFM库蒙特卡洛法

# %%
def FM(train_file, test_file, classification=True, rank=10, n_iter=150):
    task = 'c' if classification else 'r'
    console_output = !$LIBFM_PATH -task $task -method mcmc -train $train_file -test $test_file -iter $n_iter -dim '1,1,$rank' -out output_.libfm
    print(console_output)
    libfm_pred = pd.read_csv('output_.libfm', header=None).values.flatten()
    return libfm_pred

# %%
train_file = '../dataset/recsys_train_scaling.txt'
test_file = '../dataset/recsys_test_scaling.txt'
libfm_predict = FM(train_file, test_file, classification=False)
# Out:
# ['----------------------------------------------------------------------------', 'libFM', '  Version: 1.40', '  Author:  Steffen Rendle, steffen.rendle@uni-konstanz.de', '  WWW:     http://www.libfm.org/', '  License: Free for academic use. See license.txt.', '----------------------------------------------------------------------------', 'Loading train...\t', 'has x = 0', 'has xt = 1', 'num_rows=180000\tnum_values=3546761\tnum_features=43772\tmin_target=2\tmax_target=10', 'Loading test... \t', 'has x = 0', 'has xt = 1', 'num_rows=19813\tnum_values=390516\tnum_features=43770\tmin_target=2\tmax_target=10', '#relations: 0', 'Loading meta data...\t', '#Iter=  0\tTrain=2.54765\tTest=2.59464', '#Iter=  1\tTrain=2.44985\tTest=2.54826', '#Iter=  2\tTrain=2.40291\tTest=2.51439', '#Iter=  3\tTrain=2.36168\tTest=2.48695', '#Iter=  4\tTrain=2.33111\tTest=2.46372', '#Iter=  5\tTrain=2.30215\tTest=2.44287', '#Iter=  6\tTrain=2.27456\tTest=2.42418', '#Iter=  7\tTrain=2.24887\tTest=2.40643', '#Iter=  8\tTrain=2.2296\tTest=2.39179', '#Iter=  9\tTrain=2.21046\tTest=2.37733', '#Iter= 10\tTrain=2.19027\tTest=2.36353', '#Iter= 11\tTrain=2.17494\tTest=2.35129', '#Iter= 12\tTrain=2.16115\tTest=2.34009', '#Iter= 13\tTrain=2.14869\tTest=2.32934', '#Iter= 14\tTrain=2.13795\tTest=2.31925', '#Iter= 15\tTrain=2.12919\tTest=2.30999', '#Iter= 16\tTrain=2.12115\tTest=2.30125', '#Iter= 17\tTrain=2.11215\tTest=2.29293', '#Iter= 18\tTrain=2.1061\tTest=2.28531', '#Iter= 19\tTrain=2.10327\tTest=2.278', '#Iter= 20\tTrain=2.09555\tTest=2.27095', '#Iter= 21\tTrain=2.09231\tTest=2.26434', '#Iter= 22\tTrain=2.08781\tTest=2.2584', '#Iter= 23\tTrain=2.08532\tTest=2.25228', '#Iter= 24\tTrain=2.08094\tTest=2.24664', '#Iter= 25\tTrain=2.07462\tTest=2.24121', '#Iter= 26\tTrain=2.07275\tTest=2.23639', '#Iter= 27\tTrain=2.07295\tTest=2.23137', '#Iter= 28\tTrain=2.07048\tTest=2.2268', '#Iter= 29\tTrain=2.06891\tTest=2.22209', '#Iter= 30\tTrain=2.06657\tTest=2.21751', '#Iter= 31\tTrain=2.06529\tTest=2.21335', '#Iter= 32\tTrain=2.06185\tTest=2.20972', '#Iter= 33\tTrain=2.06065\tTest=2.20578', '#Iter= 34\tTrain=2.06097\tTest=2.20214', '#Iter= 35\tTrain=2.05903\tTest=2.19871', '#Iter= 36\tTrain=2.05786\tTest=2.19543', '#Iter= 37\tTrain=2.05745\tTest=2.19236', '#Iter= 38\tTrain=2.0552\tTest=2.18944', '#Iter= 39\tTrain=2.0543\tTest=2.18656', '#Iter= 40\tTrain=2.05342\tTest=2.184', '#Iter= 41\tTrain=2.05172\tTest=2.18145', '#Iter= 42\tTrain=2.05307\tTest=2.17891', '#Iter= 43\tTrain=2.05201\tTest=2.17647', '#Iter= 44\tTrain=2.05163\tTest=2.17403', '#Iter= 45\tTrain=2.0501\tTest=2.17169', '#Iter= 46\tTrain=2.04844\tTest=2.16933', '#Iter= 47\tTrain=2.0489\tTest=2.16717', '#Iter= 48\tTrain=2.04827\tTest=2.16504', '#Iter= 49\tTrain=2.04749\tTest=2.16307', '#Iter= 50\tTrain=2.0476\tTest=2.16102', '#Iter= 51\tTrain=2.04655\tTest=2.15918', '#Iter= 52\tTrain=2.04632\tTest=2.15723', '#Iter= 53\tTrain=2.04532\tTest=2.15546', '#Iter= 54\tTrain=2.04451\tTest=2.15375', '#Iter= 55\tTrain=2.0444\tTest=2.15202', '#Iter= 56\tTrain=2.04377\tTest=2.15041', '#Iter= 57\tTrain=2.04386\tTest=2.14883', '#Iter= 58\tTrain=2.04469\tTest=2.14729', '#Iter= 59\tTrain=2.04413\tTest=2.14587', '#Iter= 60\tTrain=2.04199\tTest=2.14454', '#Iter= 61\tTrain=2.04226\tTest=2.14319', '#Iter= 62\tTrain=2.04219\tTest=2.14193', '#Iter= 63\tTrain=2.04319\tTest=2.14066', '#Iter= 64\tTrain=2.04105\tTest=2.13943', '#Iter= 65\tTrain=2.04198\tTest=2.13826', '#Iter= 66\tTrain=2.04091\tTest=2.13699', '#Iter= 67\tTrain=2.0398\tTest=2.13585', '#Iter= 68\tTrain=2.03925\tTest=2.1346', '#Iter= 69\tTrain=2.04024\tTest=2.13359', '#Iter= 70\tTrain=2.04031\tTest=2.13262', '#Iter= 71\tTrain=2.03929\tTest=2.13164', '#Iter= 72\tTrain=2.03806\tTest=2.13066', '#Iter= 73\tTrain=2.03683\tTest=2.12981', '#Iter= 74\tTrain=2.03769\tTest=2.12892', '#Iter= 75\tTrain=2.03884\tTest=2.12796', '#Iter= 76\tTrain=2.03829\tTest=2.12713', '#Iter= 77\tTrain=2.03863\tTest=2.12629', '#Iter= 78\tTrain=2.03662\tTest=2.12549', '#Iter= 79\tTrain=2.0374\tTest=2.12465', '# ...

# %%
train_file_without_escape_path = '../dataset/recsys_test_scaling.txt'

# %%
from sklearn.datasets import load_svmlight_file

def get_test_data(path):
    data = load_svmlight_file(path)
    return data[0], data[1]

# %%
X, y = get_test_data(train_file_without_escape_path)

# %%
y
# Out:
# array([ 8.,  8.,  8., ..., 10., 10.,  8.])

# %%
libfm_predict_series = pd.Series(libfm_predict)

# %%
libfm_predict_series_int = libfm_predict_series.apply(lambda x: int(x))

# %%
libfm_predict_series_int.tolist()
# Out:
# [8,
#  7,
#  7,
#  3,
#  6,
#  7,
#  4,
#  4,
#  8,
#  8,
#  7,
#  4,
#  4,
#  9,
#  6,
#  5,
#  7,
#  8,
#  8,
#  9,
#  8,
#  8,
#  4,
#  9,
#  4,
#  7,
#  8,
#  8,
#  8,
#  5,
#  7,
#  9,
#  7,
#  7,
#  8,
#  8,
#  7,
#  8,
#  8,
#  8,
#  4,
#  7,
#  8,
#  8,
#  4,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  5,
#  7,
#  8,
#  7,
#  5,
#  4,
#  7,
#  6,
#  8,
#  6,
#  7,
#  8,
#  5,
#  7,
#  8,
#  4,
#  6,
#  7,
#  7,
#  5,
#  7,
#  7,
#  7,
#  4,
#  4,
#  8,
#  6,
#  9,
#  7,
#  8,
#  8,
#  7,
#  7,
#  3,
#  6,
#  7,
#  2,
#  4,
#  7,
#  6,
#  8,
#  3,
#  8,
#  8,
#  6,
#  7,
#  8,
#  7,
#  8,
#  8,
#  6,
#  4,
#  5,
#  8,
#  8,
#  3,
#  8,
#  6,
#  6,
#  8,
#  8,
#  9,
#  8,
#  7,
#  7,
#  6,
#  8,
#  4,
#  8,
#  8,
#  8,
#  6,
#  7,
#  8,
#  7,
#  5,
#  6,
#  6,
#  4,
#  7,
#  6,
#  6,
#  7,
#  7,
#  7,
#  7,
#  7,
#  5,
#  8,
#  5,
#  4,
#  7,
#  6,
#  4,
#  8,
#  8,
#  6,
#  4,
#  6,
#  7,
#  6,
#  8,
#  8,
#  7,
#  8,
#  6,
#  5,
#  6,
#  8,
#  5,
#  8,
#  6,
#  8,
#  6,
#  6,
#  9,
#  4,
#  4,
#  9,
#  6,
#  5,
#  4,
#  6,
#  8,
#  6,
#  9,
#  7,
#  4,
#  6,
#  5,
#  8,
#  7,
#  8,
#  4,
#  5,
#  5,
#  7,
#  6,
#  6,
#  4,
#  6,
#  8,
#  3,
#  7,
#  7,
#  4,
#  6,
#  8,
#  8,
#  8,
#  7,
#  7,
#  6,
#  7,
#  5,
#  8,
#  7,
#  4,
#  5,
#  7,
#  7,
#  3,
#  5,
#  9,
#  8,
#  9,
#  6,
#  8,
#  6,
#  5,
#  7,
#  6,
#  6,
#  6,
#  8,
#  4,
#  8,
#  4,
#  7,
#  5,
#  6,
#  7,
#  7,
#  7,
#  7,
#  6,
#  7,
#  4,
#  4,
#  4,
#  3,
#  7,
#  7,
#  4,
#  7,
#  8,
#  6,
#  7,
#  8,
#  6,
#  7,
#  4,
#  9,
#  8,
#  8,
#  7,
#  7,
#  7,
#  8,
#  9,
#  6,
#  7,
#  7,
#  5,
#  7,
#  6,
#  7,
#  5,
#  7,
#  7,
#  7,
#  6,
#  8,
#  7,
#  7,
#  6,
#  7,
#  4,
#  5,
#  6,
#  5,
#  8,
#  7,
#  7,
#  7,
#  7,
#  5,
#  6,
#  7,
#  4,
#  5,
#  7,
#  8,
#  7,
#  7,
#  8,
#  8,
#  8,
#  7,
#  6,
#  8,
#  9,
#  3,
#  7,
#  8,
#  8,
#  8,
#  7,
#  7,
#  4,
#  8,
#  8,
#  7,
#  9,
#  8,
#  7,
#  8,
#  8,
#  6,
#  5,
#  6,
#  8,
#  8,
#  4,
#  8,
#  8,
#  6,
#  6,
#  5,
#  8,
#  8,
#  4,
#  7,
#  5,
#  8,
#  8,
#  8,
#  7,
#  6,
#  8,
#  6,
#  7,
#  6,
#  7,
#  7,
#  4,
#  8,
#  7,
#  6,
#  8,
#  8,
#  7,
#  9,
#  6,
#  7,
#  3,
#  7,
#  6,
#  6,
#  6,
#  8,
#  8,
#  7,
#  7,
#  7,
#  6,
#  7,
#  8,
#  6,
#  7,
#  8,
#  7,
#  9,
#  5,
#  4,
#  4,
#  4,
#  7,
#  7,
#  6,
#  7,
#  4,
#  8,
#  4,
#  5,
#  7,
#  7,
#  3,
#  8,
#  7,
#  6,
#  7,
#  7,
#  8,
#  5,
#  3,
#  7,
#  9,
#  5,
#  6,
#  8,
#  6,
#  4,
#  4,
#  8,
#  6,
#  8,
#  8,
#  8,
#  9,
#  9,
#  4,
#  8,
#  8,
#  7,
#  8,
#  8,
#  8,
#  7,
#  6,
#  7,
#  7,
#  8,
#  5,
#  8,
#  8,
#  9,
#  5,
#  4,
#  7,
#  8,
#  5,
#  4,
#  9,
#  8,
#  5,
#  7,
#  8,
#  7,
#  6,
#  8,
#  8,
#  8,
#  8,
#  8,
#  6,
#  3,
#  6,
#  6,
#  5,
#  6,
#  4,
#  8,
#  8,
#  8,
#  8,
#  4,
#  5,
#  8,
#  8,
#  6,
#  7,
#  7,
#  8,
#  4,
#  8,
#  6,
#  6,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  3,
#  8,
#  8,
#  5,
#  7,
#  7,
#  4,
#  7,
#  7,
#  4,
#  6,
#  6,
#  7,
#  8,
#  6,
#  4,
#  6,
#  8,
#  8,
#  7,
#  3,
#  8,
#  4,
#  6,
#  6,
#  4,
#  5,
#  5,
#  8,
#  6,
#  6,
#  8,
#  7,
#  8,
#  8,
#  5,
#  7,
#  4,
#  5,
#  7,
#  6,
#  5,
#  5,
#  8,
#  7,
#  7,
#  9,
#  5,
#  7,
#  6,
#  6,
#  7,
#  8,
#  8,
#  6,
#  4,
#  5,
#  9,
#  6,
#  6,
#  6,
#  7,
#  8,
#  5,
#  7,
#  7,
#  6,
#  6,
#  9,
#  5,
#  5,
#  7,
#  8,
#  7,
#  7,
#  8,
#  7,
#  5,
#  8,
#  8,
#  7,
#  6,
#  8,
#  4,
#  8,
#  7,
#  4,
#  4,
#  8,
#  9,
#  9,
#  8,
#  6,
#  6,
#  8,
#  8,
#  6,
#  7,
#  4,
#  8,
#  3,
#  7,
#  6,
#  7,
#  8,
#  8,
#  8,
#  4,
#  7,
#  7,
#  7,
#  4,
#  6,
#  7,
#  8,
#  7,
#  9,
#  4,
#  8,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  3,
#  4,
#  3,
#  7,
#  4,
#  6,
#  4,
#  6,
#  8,
#  8,
#  7,
#  6,
#  4,
#  8,
#  7,
#  5,
#  7,
#  7,
#  3,
#  5,
#  7,
#  8,
#  9,
#  8,
#  8,
#  4,
#  6,
#  6,
#  7,
#  4,
#  4,
#  7,
#  8,
#  8,
#  8,
#  8,
#  7,
#  5,
#  5,
#  7,
#  4,
#  7,
#  4,
#  7,
#  7,
#  5,
#  8,
#  7,
#  8,
#  9,
#  7,
#  5,
#  7,
#  7,
#  7,
#  8,
#  5,
#  7,
#  9,
#  7,
#  9,
#  7,
#  7,
#  6,
#  4,
#  7,
#  6,
#  6,
#  7,
#  9,
#  4,
#  7,
#  6,
#  4,
#  8,
#  7,
#  8,
#  7,
#  7,
#  4,
#  4,
#  7,
#  7,
#  6,
#  5,
#  4,
#  8,
#  8,
#  5,
#  8,
#  3,
#  3,
#  9,
#  8,
#  6,
#  5,
#  5,
#  5,
#  6,
#  8,
#  9,
#  8,
#  8,
#  8,
#  8,
#  9,
#  8,
#  8,
#  7,
#  6,
#  8,
#  9,
#  5,
#  9,
#  9,
#  7,
#  6,
#  9,
#  7,
#  7,
#  8,
#  8,
#  6,
#  7,
#  7,
#  6,
#  9,
#  5,
#  8,
#  8,
#  7,
#  8,
#  5,
#  6,
#  4,
#  8,
#  8,
#  4,
#  9,
#  7,
#  7,
#  9,
#  9,
#  7,
#  2,
#  8,
#  8,
#  7,
#  7,
#  8,
#  9,
#  7,
#  4,
#  4,
#  7,
#  8,
#  8,
#  8,
#  5,
#  8,
#  8,
#  7,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  5,
#  6,
#  5,
#  7,
#  7,
#  4,
#  7,
#  7,
#  4,
#  6,
#  7,
#  4,
#  7,
#  8,
#  6,
#  5,
#  7,
#  8,
#  7,
#  4,
#  4,
#  5,
#  8,
#  7,
#  8,
#  4,
#  4,
#  8,
#  5,
#  8,
#  6,
#  7,
#  8,
#  8,
#  8,
#  4,
#  7,
#  8,
#  8,
#  7,
#  8,
#  8,
#  6,
#  8,
#  5,
#  4,
#  8,
#  9,
#  8,
#  7,
#  7,
#  7,
#  8,
#  5,
#  9,
#  5,
#  8,
#  8,
#  9,
#  4,
#  8,
#  6,
#  7,
#  9,
#  8,
#  8,
#  7,
#  5,
#  4,
#  6,
#  7,
#  8,
#  6,
#  8,
#  4,
#  9,
#  8,
#  7,
#  7,
#  7,
#  6,
#  6,
#  7,
#  6,
#  4,
#  6,
#  6,
#  6,
#  8,
#  5,
#  7,
#  8,
#  8,
#  4,
#  4,
#  5,
#  6,
#  6,
#  7,
#  8,
#  8,
#  9,
#  5,
#  4,
#  9,
#  4,
#  5,
#  8,
#  4,
#  6,
#  6,
#  5,
#  7,
#  8,
#  7,
#  4,
#  7,
#  7,
#  7,
#  4,
#  4,
#  4,
#  5,
#  7,
#  7,
#  6,
#  6,
#  8,
#  7,
#  7,
#  6,
#  6,
#  7,
#  8,
#  4,
#  4,
#  7,
#  4,
#  7,
#  7,
#  6,
#  7,
#  7,
#  7,
#  7,
#  8,
#  5,
#  8,
#  7,
#  6,
#  6,
#  5,
#  4,
#  7,
#  7,
#  7,
#  6,
#  6,
#  7,
#  7,
#  8,
#  7,
#  4,
#  7,
#  7,
#  9,
#  8,
#  9,
#  5,
#  6,
#  5,
#  6,
#  7,
#  5,
#  9,
#  5,
#  8,
#  7,
#  9,
#  9,
#  4,
#  7,
#  6,
#  6,
#  4,
#  7,
#  5,
#  6,
#  4,
#  7,
#  4,
#  8,
#  7,
#  6,
#  5,
#  7,
#  8,
#  6,
#  8,
#  8,
#  6,
#  6,
#  7,
#  4,
#  9,
#  7,
#  9,
#  8,
#  7,
#  8,
#  8,
#  4,
#  7,
#  4,
#  4,
#  8,
#  5,
#  7,
#  5,
#  5,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  5,
#  8,
#  6,
#  ...]

# %%
y
# Out:
# array([ 8.,  8.,  8., ..., 10., 10.,  8.])

# %% [markdown]
# ## 转换为评分后的测试集MSE

# %%
mean_squared_error(y, libfm_predict_series_int.tolist())
# Out:
# 4.676727401201232

# %%
mean_squared_error(y, libfm_predict_series.tolist())
# Out:
# 4.384792147533347

# %%
y[0:10]
# Out:
# array([ 8.,  8.,  8.,  4., 10., 10.,  4.,  4.,  8., 10.])

# %%
libfm_predict_series[100:500]
# Out:
# 100    7.34519
# 101    8.77586
# 102    8.65679
# 103    6.59199
# 104    4.44896
# 105    5.88468
# 106    8.01670
# 107    8.73353
# 108    3.67003
# 109    8.73270
# 110    6.67533
# 111    6.72056
# 112    8.27252
# 113    8.34008
# 114    9.35346
# 115    8.23754
# 116    7.88176
# 117    7.02376
# 118    6.62872
# 119    8.50161
# 120    4.00111
# 121    8.87787
# 122    8.46534
# 123    8.18763
# 124    6.36202
# 125    7.86422
# 126    8.11483
# 127    7.13508
# 128    5.26463
# 129    6.07317
#         ...
# 470    6.50967
# 471    7.42814
# 472    7.76787
# 473    7.18996
# 474    7.04490
# 475    7.19295
# 476    8.28238
# 477    3.87494
# 478    8.38499
# 479    8.26623
# 480    5.77554
# 481    7.41266
# 482    7.62928
# 483    4.75189
# 484    7.42415
# 485    7.27891
# 486    4.51170
# 487    6.18790
# 488    6.02756
# 489    7.73879
# 490    8.43980
# 491    6.86265
# 492    4.76168
# 493    6.59557
# 494    8.57539
# 495    8.32975
# 496    7.92331
# 497    3.82961
# 498    8.57978
# 499    4.33842
# Length: 400, dtype: float64

# %% [markdown]
# ## 向量转换器

# %%
v_from_pkl = None
with open('../dataset/dict2vec', 'rb') as f:
    v_from_pkl = pkl.load(f)

# %% [markdown]
# ## 频度统计字典

# %%
actors_dict = None
director_dict = None

with open('../dataset/actors_dict', 'rb') as f:
    actors_dict = pkl.load(f)
with open('../dataset/director_dict', 'rb') as f:
    director_dict = pkl.load(f)

# %% [markdown]
# ## 与训练样本一样的方式构建预测数据的输入矩阵

# %%
def convert_dataframe_2_dict_list(df_main, actors_dict, director_dict):
    data_dict_list = []
    for i in df_main.index:
        _dict = {}
        is_invalid = False
        #type
        for s_type in df_main.iloc[i]['type'].split('|'):
            _dict[s_type] = 1
        #actors
        for s_actor in df_main.iloc[i]['actors'].split('|'):
            if not s_actor in actors_dict:
                print('invalid data index is ' + str(i))
                invalid_data_list.append(i)
                is_invalid = True
                break
            if actors_dict[s_actor] < 2:
                _dict['other_actor'] = 1
            else:
                _dict[s_actor] = 1
        if is_invalid == True:
          continue;
        #regios
        _dict[df_main.iloc[i]['region']] = 1
        #userid ...
        _dict[df_main.iloc[i]['UserId']] = 1
        _dict[str(df_main.iloc[i]['MovieId'])] = 1
        _dict['rat'] = df_main.iloc[i]['rat']
        _dict['rmax'] = df_main.iloc[i]['rmax']
        _dict['rmin'] = df_main.iloc[i]['rmin']
        _dict['ravg'] = df_main.iloc[i]['ravg']
        _dict['rcount'] = df_main.iloc[i]['rcount']
        _dict['rsum'] = df_main.iloc[i]['rsum']
        _dict['rmedian'] = df_main.iloc[i]['rmedian']
        _dict['TIME_DIS'] = df_main.iloc[i]['TIME_DIS']
        #director
        for s_director in df_main.iloc[i]['director'].split('|'):
            if director_dict[s_director] < 2:
                _dict['other_director'] = 1
            else:
                _dict[s_director] = 1
        #trait
        for s_trait in df_main.iloc[i]['trait'].split('|'):
            _dict[s_trait] = 1
        data_dict_list.append(_dict)
    return data_dict_list

# %%
df_data = df_data.fillna(0)  # 无新的数据，不能实验推荐预测
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-c09e1d95253d> in <module>()
# ----> 1 df_data = df_data.fillna(0)
#
# NameError: name 'df_data' is not defined

# %%
dict_list = convert_dataframe_2_dict_list(df_data, actors_list, director_list)

# %%
dict_list

# %%
predict_X = v_from_pkl.transform(dict_list)

# %%
predict_file = '../dataset/recsys_predict.txt'

dump_svmlight_file(predict_X, np.zeros(predict_X.shape[0]), predict_file_)

# %%
libfm_predict_final = FM(train_file, predict_file, classification=True)

# %%
libfm_predict_final

# %% [markdown]
# ## 调用FM打分

# %%
train_file_lr_path = '../dataset/recsys_train_scaling_lr.txt'
test_file_lr_path = '../dataset/recsys_test_scaling_lr.txt'

# %%
train_lr_path = '../dataset/recsys_train_lr.txt'

# %%
train_X_lr, train_y = get_test_data(train_lr_path)

# %%
test_X_lr, test_y = get_test_data(test_file_lr_path)

# %% [markdown]
# ## LR模型fit

# %%
lr = LogisticRegression(C=0.01, penalty='l2')
lr.fit(train_X_lr, train_y)

# %%
train_X_4_scale, train_y_4_scale = get_test_data(train_lr_path)

# %%
train_X_4_scale.shape

# %%
train_y_4_scale[train_y_4_scale == 1].shape

# %% [markdown]
# ## LR预测（最终实现参考recsys_core）

# %%
scaler = preprocessing.MaxAbsScaler()
scaler.fit(train_X_4_scale)

# %%
temp_one = v_from_pkl.transform({})

# %%
temp_one_X = scaler.transform(temp_one)

# %%
temp_one_X[temp_one_X != 0]

# %%
predict_X = scaler.transform(predict_X)

# %%
lr_predict_final = lr.predict_proba(temp_one)

# %%
lr_predict_final
