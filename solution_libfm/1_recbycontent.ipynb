# %% [markdown]
# ## 读取电影数据

# %%
import tqdm
from functools import reduce
import pandas as pd
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics.pairwise import pairwise_distances

# %%
df = pd.read_csv("../dataset/processed_movies.csv")
df.head()
# Out:
#                                               actors           director  \
# 0  杰夫里·乔 Jeffrey Chyau|姜星 Sung Kang|吴玉 Jade Wu|萨曼...  迈克·姜 Michael Kang
# 1                             海瑟·格拉汉姆|杰瑞·奥康奈尔|约翰·考伯特   Brian Herzlinger
# 2              史蒂夫·卡瑞尔|摩根·弗里曼|劳伦·格拉汉姆|约翰尼·西蒙斯|约翰·古德曼            汤姆·沙迪亚克
# 3             安吉拉·兰斯伯瑞|杰拉丁·卓别林|托尼·柯蒂斯|爱德华·福克斯|罗克·赫德森            盖伊·汉弥尔顿
# 4                            北野武|浅野忠信|大楠道代|夏川结衣|岸部一德                北野武
#
#      name  rat region    traits            type  movie_id
# 0    汽车旅馆  7.0     美国     青春|文艺           喜剧|剧情         1
# 1  安吉拉怀孕记  5.7     美国        女性           爱情|喜剧         2
# 2   冒牌天神2  6.5     美国  魔幻|励志|搞笑     科幻|喜剧|奇幻|剧情         3
# 3   破镜谋杀案  7.0     英国        经典        悬疑|惊悚|犯罪         4
# 4     座头市  8.0     日本        经典  音乐|犯罪|动作|剧情|武侠         5

# %%
df.shape
# Out:
# (23034, 8)

# %% [markdown]
# ## 对type, actors, director, trait四个类型数据分别构建一个频度统计字典，用于之后的one-hot编码

# %%
def get_dim_dict(df, dim_name):
    type_list = list(map(lambda x: x.split('|'), df[dim_name]))
    type_list = [x for l in type_list for x in l]
    def reduce_func(x, y):
        for i in x:
            if i[0] == y[0][0]:
                x.remove(i)
                x.append(((i[0], i[1] + 1)))
                return x
        x.append(y[0])
        return x
    l = filter(lambda x: x != None, map(lambda x: [(x, 1)], type_list))
    type_zip = reduce(reduce_func, list(l))
    type_dict = {}
    for i in type_zip:
        type_dict[i[0]] = i[1]
    return type_dict

# %%
type_dict = get_dim_dict(df, 'type')
print(type_dict['历史'])
# Out:
# 1295

# %%
actors_dict = get_dim_dict(df, 'actors')
print(actors_dict['金标'])
# Out:
# 1

# %%
director_dict = get_dim_dict(df, 'director')
print(director_dict['吴思远'])
# Out:
# 5

# %%
trait_dict = get_dim_dict(df, 'traits')
print(trait_dict['经典'])
# Out:
# 5994

# %% [markdown]
# ## 删除无用或冗余维度

# %%
df_ = df.drop(['name', 'rat', 'movie_id'], axis=1)

# %% [markdown]
# ## 将电影数据转换为字典列表，由于演员和导演均过万维，实际计算时过于稀疏，当演员或导演只出现一次时，标记为冷门演员或导演

# %%
movie_dict_list = []
for i in df_.index:
    movie_dict = {}
    # type
    for s_type in df_.iloc[i]['type'].split('|'):
        movie_dict[s_type] = 1
    # actors
    for s_actor in df_.iloc[i]['actors'].split('|'):
        if actors_dict[s_actor] < 2:
            movie_dict['other_actor'] = 1
        else:
            movie_dict[s_actor] = 1
    # regions
    movie_dict[df_.iloc[i]['region']] = 1
    # director
    for s_director in df_.iloc[i]['director'].split('|'):
        if director_dict[s_director] < 2:
            movie_dict['other_director'] = 1
        else:
            movie_dict[s_director] = 1
    # trait
    for s_trait in df_.iloc[i]['traits'].split('|'):
        movie_dict[s_trait] = 1
    movie_dict_list.append(movie_dict)

# %%
movie_dict_list
# Out:
# [{'喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '海瑟·格拉汉姆': 1,
#   '杰瑞·奥康奈尔': 1,
#   '约翰·考伯特': 1,
#   '美国': 1,
#   'other_director': 1,
#   '女性': 1},
#  {'科幻': 1,
#   '喜剧': 1,
#   '奇幻': 1,
#   '剧情': 1,
#   '史蒂夫·卡瑞尔': 1,
#   '摩根·弗里曼': 1,
#   '劳伦·格拉汉姆': 1,
#   '约翰尼·西蒙斯': 1,
#   '约翰·古德曼': 1,
#   '美国': 1,
#   '汤姆·沙迪亚克': 1,
#   '魔幻': 1,
#   '励志': 1,
#   '搞笑': 1},
#  {'悬疑': 1,
#   '惊悚': 1,
#   '犯罪': 1,
#   '安吉拉·兰斯伯瑞': 1,
#   '杰拉丁·卓别林': 1,
#   '托尼·柯蒂斯': 1,
#   '爱德华·福克斯': 1,
#   '罗克·赫德森': 1,
#   '英国': 1,
#   '盖伊·汉弥尔顿': 1,
#   '经典': 1},
#  {'音乐': 1,
#   '犯罪': 1,
#   '动作': 1,
#   '剧情': 1,
#   '武侠': 1,
#   '北野武': 1,
#   '浅野忠信': 1,
#   '大楠道代': 1,
#   '夏川结衣': 1,
#   '岸部一德': 1,
#   '日本': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '冒险': 1,
#   '喜剧': 1,
#   '马克·韦伯': 1,
#   '泽娜·格雷': 1,
#   '埃曼纽尔·施莱琪': 1,
#   '克里斯·艾略特': 1,
#   '珍·斯马特': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '周迅': 1,
#   '佟大为': 1,
#   '钟汉良': 1,
#   '张梓琳': 1,
#   '郭书瑶': 1,
#   '中国大陆': 1,
#   '郭在容': 1,
#   '青春': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '陈小春': 1,
#   '罗家英': 1,
#   '富田靖子': 1,
#   '莫文蔚': 1,
#   '日本': 1,
#   '严浩': 1,
#   '文艺': 1},
#  {'冒险': 1,
#   '米基·鲁尼': 1,
#   '库尔特·拉塞尔': 1,
#   'other_actor': 1,
#   '杰克·艾伯森': 1,
#   '美国': 1,
#   'other_director': 1,
#   'Ted Berman': 1,
#   '经典': 1},
#  {'同性': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '乌比·戈德堡': 1,
#   '玛丽·露易斯·帕克': 1,
#   '德鲁·巴里摩尔': 1,
#   '马修·麦康纳': 1,
#   '法国': 1,
#   '赫伯特·罗斯': 1,
#   '女性': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '同性': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'Joseph Graham': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'犯罪': 1,
#   '爱情': 1,
#   '动作': 1,
#   '剧情': 1,
#   '惊悚': 1,
#   '利亚姆·海姆斯沃斯': 1,
#   '道恩·强森': 1,
#   '艾玛·罗伯茨': 1,
#   '迈克尔·安格拉诺': 1,
#   '妮基·瑞德': 1,
#   'John Leguizamo': 1,
#   'other_actor': 1,
#   'Denise Richards': 1,
#   '美国': 1,
#   'other_director': 1,
#   '黑帮': 1},
#  {'悬疑': 1, 'other_actor': 1, '法国': 1, 'Marc Rivière': 1, '文艺': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '娜奥米·沃茨': 1,
#   '杰顿·李博赫': 1,
#   '雅各布·特伦布莱': 1,
#   '萨拉·西尔弗曼': 1,
#   '迪恩·诺里斯': 1,
#   '美国': 1,
#   '科林·特雷沃罗': 1,
#   '青春': 1},
#  {'喜剧': 1,
#   '音乐': 1,
#   '奇幻': 1,
#   '贾斯汀·朗': 1,
#   '安娜·法瑞丝': 1,
#   '马修·格雷·古柏勒': 1,
#   '克里斯蒂娜·艾伯盖特': 1,
#   '杰森·李': 1,
#   '美国': 1,
#   '贝蒂·托马斯': 1,
#   '搞笑': 1},
#  {'剧情': 1, 'other_actor': 1, '法国': 1, 'other_director': 1, '文艺': 1},
#  {'爱情': 1, '同性': 1, 'other_actor': 1, '英国': 1, 'other_director': 1, '青春': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '平采娜·乐维瑟派布恩': 1,
#   '马里奥·毛瑞尔': 1,
#   '苏达拉·布查蓬': 1,
#   'other_actor': 1,
#   '诺特·阿查拉那·阿瑞亚卫考': 1,
#   '泰国': 1,
#   'other_director': 1,
#   '华森·波克彭': 1,
#   '感人': 1,
#   '青春': 1,
#   '搞笑': 1,
#   '励志': 1,
#   '文艺': 1,
#   '经典': 1},
#  {'犯罪': 1, '剧情': 1, 'other_actor': 1, '瑞典': 1, 'other_director': 1, '女性': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '斯科特·斯比德曼': 1,
#   '雷切尔·布兰卡德': 1,
#   '肯尼斯·威尔什': 1,
#   '戴文·博斯蒂克': 1,
#   '加拿大': 1,
#   '阿托姆·伊戈扬': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'科幻': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '惊悚': 1,
#   '水野真紀': 1,
#   '萩原聖人': 1,
#   '日本': 1,
#   '松田秀知': 1,
#   '佐藤祐市': 1,
#   '魔幻': 1},
#  {'爱情': 1,
#   '冒险': 1,
#   '喜剧': 1,
#   '奇幻': 1,
#   '麦克·梅尔斯': 1,
#   '艾迪·墨菲': 1,
#   '卡梅隆·迪亚兹': 1,
#   '朱莉·安德鲁斯': 1,
#   '安东尼奥·班德拉斯': 1,
#   '美国': 1,
#   '安德鲁·亚当森': 1,
#   '凯利·阿斯博瑞': 1,
#   '康拉德·弗农': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '佐藤宽太': 1,
#   '美沙玲奈': 1,
#   '阵内孝则': 1,
#   '石冢 英彦': 1,
#   '石田光': 1,
#   '日本': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '西格妮·韦弗': 1,
#   '霍利·亨特': 1,
#   '德蒙特·莫罗尼': 1,
#   '威廉·麦克纳马拉': 1,
#   '小哈里·康尼克': 1,
#   '美国': 1,
#   '乔恩·阿米尔': 1,
#   '女性': 1},
#  {'犯罪': 1,
#   '动作': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '吴镇宇': 1,
#   '李丽珍': 1,
#   '苏志威': 1,
#   '丁子峻': 1,
#   '张睿羚': 1,
#   '香港': 1,
#   '查传谊': 1,
#   '黑帮': 1},
#  {'爱情': 1,
#   '科幻': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '西蒙·佩吉': 1,
#   '凯特·贝金赛尔': 1,
#   '罗宾·威廉姆斯': 1,
#   '罗伯·里格尔': 1,
#   '特瑞·吉列姆': 1,
#   '英国': 1,
#   '特瑞·琼斯': 1,
#   '魔幻': 1,
#   '搞笑': 1},
#  {'科幻': 1,
#   '惊悚': 1,
#   '奇幻': 1,
#   '矶部勉': 1,
#   '山寺宏一': 1,
#   '千叶繁': 1,
#   '高岛雅罗': 1,
#   '日本': 1,
#   '大友克洋': 1,
#   '森本晃司': 1,
#   '经典': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   'Hara': 1,
#   'Jared Leto': 1,
#   'Christina Ricci': 1,
#   'Gabriel Byrne': 1,
#   '丹麦': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '科幻': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '艾格尼丝·布鲁根': 1,
#   '休·丹西': 1,
#   '奥利维埃·马丁内斯': 1,
#   '美国': 1,
#   '卡蒂娅·冯·加尼尔': 1,
#   '魔幻': 1},
#  {'科幻': 1,
#   '冒险': 1,
#   '动作': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '伊恩·麦克莱恩': 1,
#   '马丁·弗瑞曼': 1,
#   '理查德·阿米蒂奇': 1,
#   '本尼迪克特·康伯巴奇': 1,
#   '奥兰多·布鲁姆': 1,
#   '美国': 1,
#   '彼得·杰克逊': 1,
#   '魔幻': 1,
#   '经典': 1},
#  {'奇幻': 1,
#   '动作': 1,
#   'other_actor': 1,
#   'Stephen Murray': 1,
#   '帕梅拉·布朗': 1,
#   '法国': 1,
#   'other_director': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '冒险': 1,
#   '奇幻': 1,
#   'other_actor': 1,
#   '法国': 1,
#   'other_director': 1,
#   '魔幻': 1,
#   '经典': 1},
#  {'犯罪': 1,
#   '动作': 1,
#   '剧情': 1,
#   '派特察泰·王卡姆劳': 1,
#   '杰佳·亚宁': 1,
#   'other_actor': 1,
#   '泰国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '张默': 1,
#   'other_actor': 1,
#   '姜武': 1,
#   '张光北': 1,
#   '中国大陆': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '科幻': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '剧情': 1,
#   '惊悚': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'other_director': 1,
#   '搞笑': 1},
#  {'歌舞': 1,
#   '音乐': 1,
#   '赵忠祥': 1,
#   'other_actor': 1,
#   '姜昆': 1,
#   '姜黎黎': 1,
#   '中国大陆': 1,
#   '黄一鹤': 1,
#   'other_director': 1,
#   '经典': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '袁牧女': 1,
#   '中国大陆': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '迈尔斯·特勒': 1,
#   '谢琳·伍德蕾': 1,
#   '布丽·拉尔森': 1,
#   '玛丽·伊丽莎白·温斯特德': 1,
#   '詹妮弗·杰森·李': 1,
#   '美国': 1,
#   '詹姆斯·庞索特': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '伊莉莎白·哈诺伊斯': 1,
#   '方·基默': 1,
#   '迪奥拉·拜尔德': 1,
#   '威廉姆·赛德勒': 1,
#   '瑞恩·马尔伽里尼': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'科幻': 1,
#   '剧情': 1,
#   '同性': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   'other_actor': 1,
#   '美国': 1,
#   '托德·海因斯': 1,
#   '文艺': 1},
#  {'喜剧': 1, '奇幻': 1, 'other_actor': 1, '中国大陆': 1, '回宇': 1, '魔幻': 1, '励志': 1},
#  {'悬疑': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '马修·麦克费登': 1,
#   '艾米丽·巴克雷': 1,
#   '米兰达·奥图': 1,
#   'other_actor': 1,
#   '英国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'喜剧': 1, '瓦妮萨·安吉尔': 1, '比尔·默瑞': 1, '美国': 1, 'other_director': 1, '励志': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '彼得·洛': 1,
#   'other_actor': 1,
#   '德国': 1,
#   '弗里茨·朗': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '意大利': 1,
#   'other_director': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '剧情': 1,
#   '蒂莫西·柴勒梅德': 1,
#   '艾米·汉莫': 1,
#   '迈克尔·斯图巴': 1,
#   '阿蜜拉·卡萨': 1,
#   '艾斯特·加瑞尔': 1,
#   '巴西': 1,
#   '卢卡·瓜达尼诺': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   'other_actor': 1,
#   '殷硕': 1,
#   '朱亚文': 1,
#   '中国大陆': 1,
#   '胡雪杨': 1,
#   'other_director': 1,
#   '经典': 1,
#   '青春': 1},
#  {'剧情': 1,
#   '沃尔特·皮金': 1,
#   '玛琳·奥哈拉': 1,
#   'other_actor': 1,
#   '唐纳德·克里斯普': 1,
#   '罗迪·麦克道尔': 1,
#   '英国': 1,
#   '约翰·福特': 1,
#   '经典': 1},
#  {'剧情': 1, '吕丽萍': 1, '孙海英': 1, '郑振瑶': 1, '中国大陆': 1, '彭小莲': 1, '女性': 1},
#  {'恐怖': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '川村雪绘': 1,
#   '斋藤工': 1,
#   '津田宽治': 1,
#   '日本': 1,
#   '友松直之': 1,
#   '西村喜广': 1,
#   '搞笑': 1},
#  {'犯罪': 1,
#   '冒险': 1,
#   '惊悚': 1,
#   '动作': 1,
#   '肖恩·康纳利': 1,
#   'other_actor': 1,
#   '英国': 1,
#   '特伦斯·杨': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '动作': 1,
#   '犯罪': 1,
#   '剧情': 1,
#   '托尼·塞尔维洛': 1,
#   'other_actor': 1,
#   '茱莉安·柯勒': 1,
#   '爱丽丝·德维尔': 1,
#   '意大利': 1,
#   '克劳迪奥·库佩利尼': 1,
#   '黑帮': 1},
#  {'爱情': 1, '剧情': 1, '徐天佑': 1, 'other_actor': 1, '香港': 1, '刘国昌': 1, '青春': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '达式常': 1,
#   '冯巩': 1,
#   'other_actor': 1,
#   '张璐': 1,
#   '中国大陆': 1,
#   '黄建新': 1,
#   '经典': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '动作': 1,
#   '冒险': 1,
#   '剧情': 1,
#   '阿兰·德龙': 1,
#   '维尔娜·丽丝': 1,
#   'other_actor': 1,
#   '阿基姆·坦米罗夫': 1,
#   '西班牙': 1,
#   '克里斯蒂昂-雅克': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '让-卢克·比洛多': 1,
#   '道格拉斯·布斯': 1,
#   '麦莉·赛勒斯': 1,
#   '诺拉·邓恩': 1,
#   '琳娜·埃斯科': 1,
#   '美国': 1,
#   '丽萨·阿祖洛斯': 1,
#   '青春': 1},
#  {'奇幻': 1, '柿原彻也': 1, '日本': 1, '石平信司': 1, '魔幻': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '妮可·基德曼': 1,
#   '哈里特·安德森': 1,
#   '劳伦·白考尔': 1,
#   '保罗·贝坦尼': 1,
#   '詹姆斯·肯恩': 1,
#   '丹麦': 1,
#   '拉斯·冯·提尔': 1,
#   '经典': 1},
#  {'犯罪': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '马龙·白兰度': 1,
#   '马修·布罗德里克': 1,
#   '布鲁诺·柯比': 1,
#   '佩内洛普·安·米勒': 1,
#   '美国': 1,
#   '安德鲁·伯格曼': 1,
#   '黑帮': 1},
#  {'犯罪': 1,
#   '动作': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '岸谷五朗': 1,
#   'other_actor': 1,
#   '日本': 1,
#   'other_director': 1,
#   '黑帮': 1},
#  {'冒险': 1,
#   '战争': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '本·斯蒂勒': 1,
#   '小罗伯特·唐尼': 1,
#   '杰克·布莱克': 1,
#   '马修·麦康纳': 1,
#   '史蒂夫·库根': 1,
#   '德国': 1,
#   '搞笑': 1},
#  {'喜剧': 1, '陈强': 1, '陈佩斯': 1, '郝岩': 1, '中国大陆': 1, '刘国权': 1, '经典': 1, '搞笑': 1},
#  {'爱情': 1,
#   '科幻': 1,
#   '奇幻': 1,
#   '剧情': 1,
#   '周迅': 1,
#   '韩庚': 1,
#   '冯绍峰': 1,
#   '袁姗姗': 1,
#   '张涵予': 1,
#   '谢欣颖': 1,
#   '张书豪': 1,
#   'other_actor': 1,
#   '中国大陆': 1,
#   '李睿珺': 1,
#   '易小星': 1,
#   'other_director': 1,
#   '杜波': 1,
#   '感人': 1,
#   '青春': 1,
#   '励志': 1,
#   '文艺': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '剧情': 1,
#   '方中信': 1,
#   '张智尧': 1,
#   '安雅': 1,
#   'other_actor': 1,
#   '夏韶声': 1,
#   '香港': 1,
#   '邓衍成': 1,
#   '黑帮': 1},
#  {'喜剧': 1,
#   '动作': 1,
#   '奇幻': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '林正英': 1,
#   '钱小豪': 1,
#   '黄子扬': 1,
#   '谷峰': 1,
#   '香港': 1,
#   '刘伟强': 1,
#   '经典': 1,
#   '搞笑': 1},
#  {'剧情': 1,
#   '本木雅弘': 1,
#   '广末凉子': 1,
#   '山崎努': 1,
#   '吉行和子': 1,
#   '笹野高史': 1,
#   '日本': 1,
#   '泷田洋二郎': 1,
#   '感人': 1,
#   '经典': 1,
#   '文艺': 1},
#  {'悬疑': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '中国大陆': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '吕中': 1,
#   '冯远征': 1,
#   '秦海璐': 1,
#   '秦昊': 1,
#   'other_actor': 1,
#   '中国大陆': 1,
#   '王小帅': 1,
#   '文艺': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '本尼迪克特·康伯巴奇': 1,
#   '马丁·弗瑞曼': 1,
#   'other_actor': 1,
#   '鲁珀特·格雷夫斯': 1,
#   '马克·加蒂斯': 1,
#   '英国': 1,
#   '道格拉斯·麦金农': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '李康生': 1,
#   '陈湘琪': 1,
#   '陆弈静': 1,
#   '苗天': 1,
#   '叶童': 1,
#   '法国': 1,
#   '蔡明亮': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'恐怖': 1,
#   '悬疑': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '杨丞琳': 1,
#   '许玮甯': 1,
#   'other_actor': 1,
#   '龙劭华': 1,
#   '黄河': 1,
#   '台湾': 1,
#   'other_director': 1,
#   '女性': 1},
#  {'爱情': 1,
#   '科幻': 1,
#   '喜剧': 1,
#   '冒险': 1,
#   '动作': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '波利斯·卡洛夫': 1,
#   'other_actor': 1,
#   '布兰登·费舍': 1,
#   '蕾切尔·薇兹': 1,
#   '约翰·汉纳': 1,
#   '阿诺德·沃斯洛': 1,
#   '凯文·J·奥康纳': 1,
#   '美国': 1,
#   'other_director': 1,
#   '魔幻': 1,
#   '经典': 1},
#  {'犯罪': 1,
#   '西部': 1,
#   '动作': 1,
#   '剧情': 1,
#   '凯文·克莱恩': 1,
#   '凯文·科斯特纳': 1,
#   '丹尼·格洛弗': 1,
#   '斯科特·格伦': 1,
#   '美国': 1,
#   '劳伦斯·卡斯丹': 1,
#   '经典': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   'Diego Luna': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'历史': 1, 'other_actor': 1, '美国': 1, 'other_director': 1, '青春': 1, '励志': 1},
#  {'爱情': 1,
#   '犯罪': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '周星驰': 1,
#   '张学友': 1,
#   '曾志伟': 1,
#   '香港': 1,
#   '柯受良': 1,
#   '搞笑': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '张铉诚': 1,
#   '朴哲民': 1,
#   '全茂松': 1,
#   '韩国': 1,
#   '柳勋': 1,
#   '青春': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '科幻': 1,
#   '冒险': 1,
#   '动作': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '本诺·菲尔曼': 1,
#   '克里斯塔娜·洛肯': 1,
#   '艾丽西亚·维特': 1,
#   '朱利安·山德斯': 1,
#   '萨缪尔·韦斯特': 1,
#   '意大利': 1,
#   '乌利·埃德尔': 1,
#   '魔幻': 1},
#  {'冒险': 1,
#   '奇幻': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '巴西': 1,
#   'other_director': 1,
#   '感人': 1,
#   '文艺': 1},
#  {'犯罪': 1,
#   '剧情': 1,
#   '吉川晃司': 1,
#   '山崎努': 1,
#   '大塚宁宁': 1,
#   '远藤宪一': 1,
#   '日本': 1,
#   '三池崇史': 1,
#   '黑帮': 1},
#  {'犯罪': 1,
#   '剧情': 1,
#   '玛丽·吉兰': 1,
#   'other_actor': 1,
#   '布鲁诺·帕特祖鲁': 1,
#   '法国': 1,
#   '贝特朗·塔维涅': 1,
#   '青春': 1},
#  {'犯罪': 1,
#   '爱情': 1,
#   '西部': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '汤姆·威兹': 1,
#   '约翰·劳瑞': 1,
#   '罗伯托·贝尼尼': 1,
#   '尼可莱塔·布拉斯基': 1,
#   '简·拉塞尔': 1,
#   'other_actor': 1,
#   '沃尔特·休斯顿': 1,
#   '意大利': 1,
#   '吉姆·贾木许': 1,
#   '经典': 1,
#   '文艺': 1},
#  {'冒险': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '安德烈·杜索里埃': 1,
#   '加拿大': 1,
#   'other_director': 1,
#   '感人': 1},
#  {'科幻': 1,
#   '冒险': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '克里斯·帕拉特': 1,
#   '佐伊·索尔达娜': 1,
#   '布莱德利·库珀': 1,
#   '范·迪塞尔': 1,
#   '戴夫·巴蒂斯塔': 1,
#   '英国': 1,
#   '詹姆斯·古恩': 1,
#   '搞笑': 1},
#  {'歌舞': 1,
#   '音乐': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   'John': 1,
#   '美国': 1,
#   'other_director': 1,
#   '经典': 1},
#  {'科幻': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '惊悚': 1,
#   '古斯塔·斯卡斯加德': 1,
#   '图娃·诺沃妮': 1,
#   'other_actor': 1,
#   '乔尔·金纳曼': 1,
#   '瑞典': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'犯罪': 1,
#   '情色': 1,
#   '剧情': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   'other_actor': 1,
#   '汤姆·伯克': 1,
#   '妮可拉·伯利': 1,
#   '朱利安·莫里斯': 1,
#   '英国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'同性': 1,
#   '剧情': 1,
#   '斯蒂芬·鲁特': 1,
#   '莫莉·香侬': 1,
#   'other_actor': 1,
#   '保罗·雷瑟': 1,
#   '雅德丽·史密斯': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '励志': 1},
#  {'犯罪': 1,
#   '爱情': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   'other_actor': 1,
#   '法国': 1,
#   'Simon Rumley': 1,
#   '经典': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '张榕容': 1,
#   '台湾': 1,
#   '陈宏一': 1,
#   '青春': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '同性': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'other_director': 1,
#   '女性': 1},
#  {'剧情': 1,
#   'Melvil Poupaud': 1,
#   'other_actor': 1,
#   '法国': 1,
#   'other_director': 1,
#   '黑帮': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '情色': 1,
#   'other_actor': 1,
#   '加拿大': 1,
#   'other_director': 1,
#   '青春': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '犯罪': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '卡勒姆·特纳': 1,
#   '格蕾丝·范·帕滕': 1,
#   'other_actor': 1,
#   '迈克·比尔比利亚': 1,
#   '玛格丽特·柯林': 1,
#   '美国': 1,
#   '亚当·里昂': 1,
#   '青春': 1},
#  {'恐怖': 1,
#   '悬疑': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   'Kate Fahy': 1,
#   '英国': 1,
#   'Simon Rumley': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'动作': 1,
#   '战争': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '罗伯特·维斯多姆': 1,
#   '澳大利亚': 1,
#   'Brian Trenchard-Smith': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '林嘉欣': 1,
#   '石锦航': 1,
#   '柯佳嬿': 1,
#   '李千娜': 1,
#   '张书豪': 1,
#   '台湾': 1,
#   '林书宇': 1,
#   '文艺': 1},
#  {'音乐': 1,
#   'other_actor': 1,
#   'Halle Berry': 1,
#   '美国': 1,
#   'Louis J': 1,
#   'Horvitz': 1,
#   '感人': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '热拉尔·德帕迪约': 1,
#   'other_actor': 1,
#   '帕特里克·伯利奇': 1,
#   '弗朗索瓦-格扎维埃·德梅松': 1,
#   '法国': 1,
#   '让·贝克': 1,
#   '感人': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '蒂莫西·斯波': 1,
#   '乔安娜·林莉': 1,
#   '艾美达·斯丹顿': 1,
#   '西莉亚·伊姆里': 1,
#   'other_actor': 1,
#   '英国': 1,
#   '理查德·隆克瑞恩': 1,
#   '感人': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'犯罪': 1,
#   '爱情': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '剧情': 1,
#   '陈世妍': 1,
#   '洪宗玄': 1,
#   '韩国': 1,
#   '金镇英': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   'other_actor': 1,
#   '韩国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '励志': 1,
#   '搞笑': 1},
#  {'冒险': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '李恩承': 1,
#   '韩国': 1,
#   'other_director': 1,
#   '经典': 1,
#   '文艺': 1,
#   '青春': 1},
#  {'冒险': 1,
#   '历史': 1,
#   '动作': 1,
#   '剧情': 1,
#   '战争': 1,
#   'other_actor': 1,
#   '拉里·巴格比': 1,
#   '美国': 1,
#   '瑞恩·雷特尔': 1,
#   '经典': 1},
#  {'剧情': 1,
#   '朱莉·德尔佩': 1,
#   '埃里克·埃尔莫斯尼诺': 1,
#   '埃玛妞·丽娃': 1,
#   '奥雷·阿蒂卡': 1,
#   '诺埃米·洛夫斯基': 1,
#   '法国': 1,
#   '文艺': 1},
#  {'犯罪': 1,
#   '科幻': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '克里斯·卡马克': 1,
#   'other_actor': 1,
#   '美国': 1,
#   '塞斯·格罗斯曼': 1,
#   '经典': 1},
#  {'犯罪': 1,
#   '动作': 1,
#   '剧情': 1,
#   '胡慧中': 1,
#   '李子雄': 1,
#   '刘青云': 1,
#   '关礼杰': 1,
#   '惠英红': 1,
#   '香港': 1,
#   '郑永潮': 1,
#   '黑帮': 1},
#  {'剧情': 1,
#   '艾米莉·德奎恩': 1,
#   '法布里齐奥·隆吉奥内': 1,
#   'other_actor': 1,
#   '奥利维埃·古尔梅': 1,
#   '法国': 1,
#   '让-皮埃尔·达内': 1,
#   '吕克·达内': 1,
#   '青春': 1,
#   '女性': 1,
#   '励志': 1,
#   '文艺': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '伊波利特·吉拉尔多': 1,
#   '帕特里克·伯利奇': 1,
#   'other_actor': 1,
#   '法国': 1,
#   'other_director': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '西部': 1,
#   '剧情': 1,
#   'Patrick Warburton': 1,
#   'Tammin Sursok': 1,
#   'Clint Black': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'Michael Damian': 1,
#   '青春': 1},
#  {'喜剧': 1,
#   '音乐': 1,
#   'other_actor': 1,
#   'Lindy Booth': 1,
#   '加拿大': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '二阶堂富美': 1,
#   '鹤田真由': 1,
#   '太贺': 1,
#   '古馆宽治': 1,
#   '杉野希妃': 1,
#   '日本': 1,
#   '深田晃司': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '音乐': 1,
#   '剧情': 1,
#   '李弘基': 1,
#   '白珍熙': 1,
#   '马东锡': 1,
#   '林元熙': 1,
#   'other_actor': 1,
#   '韩国': 1,
#   'other_director': 1,
#   '感人': 1,
#   '青春': 1,
#   '励志': 1},
#  {'爱情': 1,
#   '战争': 1,
#   '传记': 1,
#   '剧情': 1,
#   '葛丽泰·嘉宝': 1,
#   '拉蒙·诺瓦罗': 1,
#   '莱昂纳尔·巴里摩尔': 1,
#   '美国': 1,
#   'other_director': 1,
#   '经典': 1,
#   '女性': 1},
#  {'科幻': 1, '汤姆·希德勒斯顿': 1, '米歇尔·道克瑞': 1, '英国': 1, 'other_director': 1, '文艺': 1},
#  {'爱情': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   'Jonathan Rhys Meyers': 1,
#   'Sean Lawlor': 1,
#   '瑞典': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '松雪泰子': 1,
#   '柄本佑': 1,
#   'other_actor': 1,
#   '寺島進': 1,
#   '中村映里子': 1,
#   '日本': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'西部': 1,
#   '冒险': 1,
#   '动作': 1,
#   '剧情': 1,
#   '武侠': 1,
#   'other_actor': 1,
#   '孙海英': 1,
#   '香港': 1,
#   '何平': 1,
#   '经典': 1},
#  {'科幻': 1,
#   '悬疑': 1,
#   '动作': 1,
#   '山崎勝之': 1,
#   '南条弘二': 1,
#   '正岡邦夫': 1,
#   '古賀亘': 1,
#   '鵜川薫': 1,
#   '日本': 1,
#   '小原直樹': 1,
#   '魔幻': 1,
#   '经典': 1},
#  {'恐怖': 1,
#   '惊悚': 1,
#   '奇幻': 1,
#   '罗伯特·英格兰德': 1,
#   'other_actor': 1,
#   '美国': 1,
#   '斯蒂芬·霍普金斯': 1,
#   '经典': 1},
#  {'情色': 1, '剧情': 1, 'other_actor': 1, '日本': 1, 'other_director': 1, '文艺': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '托比·马奎尔': 1,
#   '查理兹·塞隆': 1,
#   '迈克尔·凯恩': 1,
#   '保罗·路德': 1,
#   '戴尔里·林多': 1,
#   '美国': 1,
#   '拉斯·霍尔斯道姆': 1,
#   '青春': 1,
#   '励志': 1,
#   '文艺': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '惊悚': 1,
#   '恐怖': 1,
#   '詹妮弗·劳伦斯': 1,
#   '伊丽莎白·苏': 1,
#   '麦克斯·泰瑞奥': 1,
#   '吉尔·贝罗斯': 1,
#   '诺兰·杰拉德·冯克': 1,
#   '加拿大': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '文森特·卡索': 1,
#   '艾玛纽尔·贝克特': 1,
#   '路易·加瑞尔': 1,
#   '伊希尔·勒·贝斯柯': 1,
#   'other_actor': 1,
#   '法国': 1,
#   '麦温': 1,
#   '经典': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '津川雅彦': 1,
#   '查理·卓别林': 1,
#   'other_actor': 1,
#   '日本': 1,
#   '吉田喜重': 1,
#   '青春': 1,
#   '经典': 1},
#  {'冒险': 1,
#   '喜剧': 1,
#   'other_actor': 1,
#   '王雪沁': 1,
#   '张洋': 1,
#   '吴凡': 1,
#   '中国大陆': 1,
#   'other_director': 1,
#   '郑成峰': 1,
#   '搞笑': 1},
#  {'科幻': 1,
#   '冒险': 1,
#   '动作': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '罗宾·邓恩': 1,
#   '朱利安·山德斯': 1,
#   '埃莉卡·杜兰斯': 1,
#   '凯瑟琳·伊莎贝尔': 1,
#   'other_actor': 1,
#   '加拿大': 1,
#   'other_director': 1,
#   '魔幻': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '加拿大': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '应采儿': 1,
#   '尹子维': 1,
#   '李茏怡': 1,
#   '森美': 1,
#   '王天林': 1,
#   '香港': 1,
#   '王晶': 1,
#   '搞笑': 1},
#  {'喜剧': 1,
#   '佐藤利奈': 1,
#   '新井里美': 1,
#   '丰崎爱生': 1,
#   '伊藤加奈惠': 1,
#   '日本': 1,
#   'other_director': 1,
#   '搞笑': 1},
#  {'同性': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '米歇尔·塞罗尔': 1,
#   '意大利': 1,
#   '埃德沃德·莫利纳罗': 1,
#   '经典': 1},
#  {'歌舞': 1,
#   '音乐': 1,
#   '剧情': 1,
#   '麦莉·赛勒斯': 1,
#   '夏洛特·兰普林': 1,
#   '安德烈·维尔姆斯': 1,
#   'other_actor': 1,
#   '意大利': 1,
#   'other_director': 1,
#   '青春': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '小弗雷迪·普林兹': 1,
#   '瑞切尔·蕾·库克': 1,
#   '马修·里沃德': 1,
#   '保罗·沃克': 1,
#   '乔迪·琳·欧基菲': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '动作': 1,
#   '剧情': 1,
#   '惊悚': 1,
#   '尚格·云顿': 1,
#   '乔·弗拉尼甘': 1,
#   'other_actor': 1,
#   '美国': 1,
#   '厄尼·巴巴拉什': 1,
#   '黑帮': 1},
#  {'爱情': 1,
#   '科幻': 1,
#   'other_actor': 1,
#   '中国大陆': 1,
#   'other_director': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'剧情': 1, 'other_actor': 1, '中国大陆': 1, '王家乙': 1, '文艺': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '约翰尼·诺克斯维尔': 1,
#   '布莱恩·考克斯': 1,
#   '凯瑟琳·海格尔': 1,
#   '美国': 1,
#   'other_director': 1,
#   '励志': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '音乐': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '德国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '李军': 1,
#   '中国大陆': 1,
#   'other_director': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'爱情': 1, '市原隼人': 1, 'other_actor': 1, '日本': 1, 'other_director': 1, '青春': 1},
#  {'犯罪': 1,
#   '动作': 1,
#   '剧情': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '约翰尼·哈里戴': 1,
#   '黄秋生': 1,
#   '林家栋': 1,
#   '林雪': 1,
#   '叶璇': 1,
#   '玛蒂尔达·鲁茨': 1,
#   'other_actor': 1,
#   '法国': 1,
#   'other_director': 1,
#   '黑帮': 1,
#   '女性': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '许冠文': 1,
#   '钟楚红': 1,
#   '黎小田': 1,
#   '董骠': 1,
#   '黄韵诗': 1,
#   '香港': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '武井证': 1,
#   '樱井孝宏': 1,
#   '能登麻美子': 1,
#   '中井和哉': 1,
#   '大塚周夫': 1,
#   '日本': 1,
#   '宇田钢之助': 1,
#   '青春': 1},
#  {'传记': 1,
#   '剧情': 1,
#   '罗伯特·帕丁森': 1,
#   '戴恩·德哈恩': 1,
#   '乔尔·埃哲顿': 1,
#   '本·金斯利': 1,
#   '克里斯汀·哈格': 1,
#   '澳大利亚': 1,
#   '安东·寇班': 1,
#   '文艺': 1},
#  {'科幻': 1,
#   '喜剧': 1,
#   '奇幻': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '乔奇': 1,
#   '海波': 1,
#   '中国大陆': 1,
#   'other_director': 1,
#   '经典': 1},
#  {'犯罪': 1,
#   '剧情': 1,
#   '比利·鲍伯·松顿': 1,
#   '卢卡斯·布莱克': 1,
#   '约翰·瑞特': 1,
#   '德怀特·尤科姆': 1,
#   'J·T·沃尔什': 1,
#   '美国': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   'Brien': 1,
#   '美国': 1,
#   'other_director': 1,
#   '励志': 1},
#  {'冒险': 1,
#   '喜剧': 1,
#   '格伦·克洛斯': 1,
#   '热拉尔·德帕迪约': 1,
#   '艾恩·格拉法德': 1,
#   '爱丽丝·伊万斯': 1,
#   'other_actor': 1,
#   '美国': 1,
#   '凯文·利玛': 1,
#   '经典': 1,
#   '搞笑': 1},
#  {'喜剧': 1, '郭晋安': 1, '杨思琦': 1, '元华': 1, '陈百祥': 1, '香港': 1, '林子皓': 1, '搞笑': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '坦纳·科恩': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '西恩·潘': 1,
#   '达科塔·范宁': 1,
#   '米歇尔·菲佛': 1,
#   '黛安·韦斯特': 1,
#   '洛雷塔·迪瓦恩': 1,
#   '美国': 1,
#   'other_director': 1,
#   '感人': 1,
#   '文艺': 1},
#  {'科幻': 1,
#   '喜剧': 1,
#   '赛斯·格林': 1,
#   '保罗·雷宾斯': 1,
#   '尼尔·帕特里克·哈里斯': 1,
#   '阿尔弗雷德·莫里纳': 1,
#   '内森·菲利安': 1,
#   '美国': 1,
#   'other_director': 1,
#   '搞笑': 1},
#  {'喜剧': 1, 'other_actor': 1, '日本': 1, 'other_director': 1, '搞笑': 1},
#  {'冒险': 1, '喜剧': 1, 'other_actor': 1, '西班牙': 1, 'other_director': 1, '搞笑': 1},
#  {'恐怖': 1,
#   '惊悚': 1,
#   '喜剧': 1,
#   '奇幻': 1,
#   '凯文·麦卡锡': 1,
#   'other_actor': 1,
#   '帕特里克·莱比奥托': 1,
#   '美国': 1,
#   'other_director': 1,
#   '魔幻': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '动作': 1,
#   '犯罪': 1,
#   '剧情': 1,
#   '谢承均': 1,
#   '白歆惠': 1,
#   '张雁名': 1,
#   '刘心悠': 1,
#   '台湾': 1,
#   '邝盛': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'传记': 1,
#   '剧情': 1,
#   '雪儿': 1,
#   '山姆·艾里奥特': 1,
#   '埃里克·斯托尔兹': 1,
#   '美国': 1,
#   '彼得·博格丹诺维奇': 1,
#   '经典': 1},
#  {'历史': 1,
#   '战争': 1,
#   '剧情': 1,
#   '贾梅尔·杜布兹': 1,
#   '萨米·纳塞利': 1,
#   '罗什迪·泽姆': 1,
#   '塞米·鲍亚吉拉': 1,
#   '伯纳德·布兰卡恩': 1,
#   '法国': 1,
#   '拉契得·波查拉': 1,
#   '经典': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '杉田智和': 1,
#   '石田彰': 1,
#   '中井和哉': 1,
#   'other_actor': 1,
#   '日本': 1,
#   '高松信司': 1,
#   '搞笑': 1},
#  {'音乐': 1,
#   'other_actor': 1,
#   '濑户麻沙美': 1,
#   '早见沙织': 1,
#   '岛崎信长': 1,
#   '花江夏树': 1,
#   '日本': 1,
#   '桥本昌和': 1,
#   '青春': 1},
#  {'犯罪': 1,
#   '动作': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '罗素·克劳': 1,
#   '海伦·斯雷特': 1,
#   '丰川悦司': 1,
#   '美国': 1,
#   'other_director': 1,
#   '黑帮': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '剧情': 1,
#   '石原裕次郎': 1,
#   '津川雅彦': 1,
#   '北原三枝': 1,
#   '芦田伸介': 1,
#   'other_actor': 1,
#   '日本': 1,
#   '中平康': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '情色': 1,
#   '同性': 1,
#   '剧情': 1,
#   '古天乐': 1,
#   '杨千嬅': 1,
#   'other_actor': 1,
#   '黄伟文': 1,
#   '罗莽': 1,
#   '贝纳·纪欧多': 1,
#   '马立克·兹迪': 1,
#   '露德温·塞尼耶': 1,
#   '香港': 1,
#   '叶伟信': 1,
#   '文艺': 1,
#   '搞笑': 1},
#  {'同性': 1,
#   '剧情': 1,
#   '米歇尔·拉罗克': 1,
#   '让-菲利普·艾科菲': 1,
#   '海伦·文森特': 1,
#   'other_actor': 1,
#   '法国': 1,
#   '亚兰·贝利内': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '历史': 1,
#   '传记': 1,
#   '剧情': 1,
#   '艾米莉·布朗特': 1,
#   '鲁伯特·弗兰德': 1,
#   '保罗·贝坦尼': 1,
#   '米兰达·理查森': 1,
#   '吉姆·布劳德本特': 1,
#   '英国': 1,
#   '让-马克·瓦雷': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'剧情': 1,
#   'Eileen April Boylan': 1,
#   'Ian Nelson': 1,
#   'J': 1,
#   'B': 1,
#   'Ghuman Jr': 1,
#   '美国': 1,
#   'John Humber': 1,
#   '文艺': 1},
#  {'剧情': 1, '赵毅维': 1, '中国大陆': 1, 'other_director': 1, '文艺': 1},
#  {'犯罪': 1,
#   '冒险': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '让·杜雅尔丹': 1,
#   '露易丝·莫诺特': 1,
#   '米歇尔·奥蒙': 1,
#   'other_actor': 1,
#   '法国': 1,
#   '米歇尔·阿扎纳维西于斯': 1,
#   '搞笑': 1},
#  {'传记': 1,
#   '动作': 1,
#   '剧情': 1,
#   '吉姆·卡维泽': 1,
#   '亚历山大·路德韦格': 1,
#   '迈克尔·切克利斯': 1,
#   '劳拉·邓恩': 1,
#   '克兰西·布朗': 1,
#   '美国': 1,
#   '托马斯·卡特': 1,
#   '青春': 1,
#   '励志': 1},
#  {'爱情': 1,
#   '历史': 1,
#   '战争': 1,
#   '剧情': 1,
#   '张丰毅': 1,
#   '张雨绮': 1,
#   '段奕宏': 1,
#   '吴刚': 1,
#   '刘威': 1,
#   '中国大陆': 1,
#   '王全安': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'传记': 1, 'other_actor': 1, '爱尔兰': 1, 'other_director': 1, '文艺': 1},
#  {'科幻': 1,
#   '悬疑': 1,
#   '冒险': 1,
#   '动作': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '休·杰克曼': 1,
#   '帕特里克·斯图尔特': 1,
#   'other_actor': 1,
#   '波伊德·霍布鲁克': 1,
#   '斯戴芬·莫昌特': 1,
#   '美国': 1,
#   '詹姆斯·曼高德': 1,
#   '感人': 1,
#   '经典': 1},
#  {'动作': 1,
#   '战争': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '克林特·伊斯特伍德': 1,
#   '玛莎·马森': 1,
#   '马里奥·范·皮布尔斯': 1,
#   '美国': 1,
#   '经典': 1},
#  {'剧情': 1,
#   'other_actor': 1,
#   'Salvatore Cantalupo': 1,
#   '意大利': 1,
#   'other_director': 1,
#   '文艺': 1},
#  {'历史': 1, '剧情': 1, 'other_actor': 1, '中国大陆': 1, 'other_director': 1, '女性': 1},
#  {'历史': 1,
#   '战争': 1,
#   '剧情': 1,
#   '文森特·斯帕诺': 1,
#   '意大利': 1,
#   '保罗·塔维亚尼': 1,
#   '维托里奥·塔维亚尼': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '本·克劳斯': 1,
#   '珍·玛奇': 1,
#   '英国': 1,
#   '马克·阿特金斯': 1,
#   '魔幻': 1},
#  {'爱情': 1,
#   '传记': 1,
#   '历史': 1,
#   '剧情': 1,
#   '战争': 1,
#   '达娜·德拉尼': 1,
#   '安娜贝丝·吉什': 1,
#   '安吉丽娜·朱莉': 1,
#   '美国': 1,
#   'other_director': 1,
#   '女性': 1},
#  {'剧情': 1,
#   '雅各布·特伦布莱': 1,
#   '朱莉娅·罗伯茨': 1,
#   'other_actor': 1,
#   '欧文·威尔逊': 1,
#   '香港': 1,
#   '斯蒂芬·卓博斯基': 1,
#   '感人': 1,
#   '励志': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '曹俊': 1,
#   '梅婷': 1,
#   '宋宁峰': 1,
#   'other_actor': 1,
#   '王千源': 1,
#   '中国大陆': 1,
#   '鄢钷': 1,
#   '青春': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'传记': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   'Barry': 1,
#   '美国': 1,
#   'other_director': 1,
#   '励志': 1},
#  {'爱情': 1,
#   '历史': 1,
#   '剧情': 1,
#   '克莱蒙·梅特耶': 1,
#   '萝拉·克雷顿': 1,
#   'other_actor': 1,
#   'Hugo Conzelmann': 1,
#   '法国': 1,
#   '奥利维耶·阿萨亚斯': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'同性': 1, '科幻': 1, 'other_actor': 1, '英国': 1, 'other_director': 1, '青春': 1},
#  {'传记': 1,
#   '剧情': 1,
#   '费·唐纳薇': 1,
#   '戴安娜·斯卡尔维德': 1,
#   '史蒂夫·弗罗斯特': 1,
#   '美国': 1,
#   'other_director': 1,
#   '女性': 1},
#  {'爱情': 1, '剧情': 1, 'other_actor': 1, '西班牙': 1, 'other_director': 1, '文艺': 1},
#  {'悬疑': 1, '音乐': 1, '陈信宏': 1, '纪培慧': 1, '台湾': 1, 'other_director': 1, '魔幻': 1},
#  {'历史': 1,
#   '动作': 1,
#   '剧情': 1,
#   '于波': 1,
#   '周韦彤': 1,
#   '班嘉佳': 1,
#   '王德顺': 1,
#   'other_actor': 1,
#   '中国大陆': 1,
#   '李晓军': 1,
#   '搞笑': 1},
#  {'恐怖': 1,
#   '惊悚': 1,
#   '喜剧': 1,
#   'other_actor': 1,
#   'Steve Howey': 1,
#   '加拿大': 1,
#   'other_director': 1,
#   '搞笑': 1},
#  {'恐怖': 1,
#   '喜剧': 1,
#   '奇幻': 1,
#   '动作': 1,
#   'other_actor': 1,
#   '付赫安琪': 1,
#   '中国大陆': 1,
#   '刘轩狄': 1,
#   '青春': 1},
#  {'剧情': 1, 'other_actor': 1, '香川照之': 1, '日本': 1, 'other_director': 1, '青春': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '大卫·杜楚尼': 1,
#   '西格妮·韦弗': 1,
#   '艾恩·格拉法德': 1,
#   '美国': 1,
#   '杰克·卡斯丹': 1,
#   '搞笑': 1},
#  {'犯罪': 1,
#   '剧情': 1,
#   '米哈伊尔·乌里扬诺夫': 1,
#   'other_actor': 1,
#   '谢尔盖·加尔马什': 1,
#   '马拉特·巴沙罗夫': 1,
#   '俄罗斯': 1,
#   '斯坦尼斯拉夫·戈沃鲁辛': 1,
#   '经典': 1},
#  {'动作': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '林子祥': 1,
#   '林青霞': 1,
#   '泰迪·罗宾': 1,
#   '徐克': 1,
#   '香港': 1,
#   'other_director': 1,
#   '经典': 1,
#   '搞笑': 1},
#  {'爱情': 1, '剧情': 1, 'other_actor': 1, '南田洋子': 1, '日本': 1, '古川卓巳': 1, '青春': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '动作': 1,
#   '剧情': 1,
#   '惊悚': 1,
#   '古天乐': 1,
#   '刘青云': 1,
#   '吴彦祖': 1,
#   '曾江': 1,
#   '叶璇': 1,
#   '香港': 1,
#   '麦兆辉': 1,
#   '庄文强': 1,
#   '经典': 1,
#   '黑帮': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '蕾切尔·沃德': 1,
#   '麦克尔·约克': 1,
#   '卡琳娜·隆巴德': 1,
#   '澳大利亚': 1,
#   '约翰·杜根': 1,
#   '文艺': 1},
#  {'剧情': 1,
#   '王柏杰': 1,
#   '田中丽奈': 1,
#   '余贵美子': 1,
#   '木村多江': 1,
#   '藤井美菜': 1,
#   '日本': 1,
#   '陈钰杰': 1,
#   '文艺': 1},
#  {'科幻': 1,
#   '恐怖': 1,
#   '灾难': 1,
#   '惊悚': 1,
#   'Paul Rae': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'Jim Wynorski': 1,
#   '魔幻': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '德国': 1,
#   'other_director': 1,
#   '女性': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '动作': 1,
#   'other_actor': 1,
#   '中国大陆': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '喜剧': 1,
#   '冒险': 1,
#   '动作': 1,
#   '剧情': 1,
#   '惊悚': 1,
#   '小罗伯特·唐尼': 1,
#   '裘德·洛': 1,
#   '瑞秋·麦克亚当斯': 1,
#   '劳米·拉佩斯': 1,
#   '斯蒂芬·弗雷': 1,
#   '英国': 1,
#   '盖·里奇': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '山下智久': 1,
#   '小松菜奈': 1,
#   '水川麻美': 1,
#   'other_actor': 1,
#   '山本美月': 1,
#   '日本': 1,
#   '熊泽尚人': 1,
#   '青春': 1},
#  {'悬疑': 1,
#   '惊悚': 1,
#   '塔拉·菲茨杰拉德': 1,
#   '贾斯蒂恩·瓦戴尔': 1,
#   '安德鲁·林肯': 1,
#   '詹姆斯·维尔比': 1,
#   '西蒙·卡洛': 1,
#   '英国': 1,
#   '蒂姆·费威尔': 1,
#   '经典': 1,
#   '女性': 1},
#  {'音乐': 1,
#   '爱情': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '惊悚': 1,
#   'other_actor': 1,
#   '韩国': 1,
#   '具惠善': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '历史': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '台湾': 1,
#   'other_director': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '犯罪': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '马克·沃尔伯格': 1,
#   'other_actor': 1,
#   '杰西卡·兰格': 1,
#   '美国': 1,
#   '鲁伯特·瓦耶特': 1,
#   '黑帮': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '朱丽叶·比诺什': 1,
#   '埃德加·拉米雷兹': 1,
#   '伊波利特·吉拉尔多': 1,
#   '法国': 1,
#   'other_director': 1,
#   '文艺': 1},
#  {'犯罪': 1,
#   '剧情': 1,
#   '本·福斯特': 1,
#   '埃米尔·赫斯基': 1,
#   '肖恩·海托西': 1,
#   '布鲁斯·威利斯': 1,
#   'other_actor': 1,
#   '美国': 1,
#   '尼克·卡萨维茨': 1,
#   '青春': 1},
#  {'传记': 1,
#   '历史': 1,
#   '动作': 1,
#   '剧情': 1,
#   '战争': 1,
#   '马志翔': 1,
#   '徐若瑄': 1,
#   'other_actor': 1,
#   '田中千绘': 1,
#   '林庆台': 1,
#   '日本': 1,
#   '魏德圣': 1,
#   '感人': 1,
#   '经典': 1},
#  {'犯罪': 1,
#   '动作': 1,
#   '冒险': 1,
#   '剧情': 1,
#   '范·迪塞尔': 1,
#   '保罗·沃克': 1,
#   '乔丹娜·布鲁斯特': 1,
#   '米歇尔·罗德里格兹': 1,
#   '尹成植': 1,
#   '德国': 1,
#   '罗伯·科恩': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '科幻': 1,
#   '悬疑': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   'Katharine Ross': 1,
#   'other_actor': 1,
#   '妮可·基德曼': 1,
#   '马修·布罗德里克': 1,
#   '贝特·米德勒': 1,
#   '格伦·克洛斯': 1,
#   '克里斯托弗·沃肯': 1,
#   '美国': 1,
#   '弗兰克·奥兹': 1,
#   '女性': 1},
#  {'历史': 1,
#   '剧情': 1,
#   '杰拉德·巴特勒': 1,
#   '韦斯·本特利': 1,
#   '约翰·瑞斯-戴维斯': 1,
#   'other_actor': 1,
#   '特里·金尼': 1,
#   '美国': 1,
#   '大卫·安斯鲍夫': 1,
#   '经典': 1,
#   '励志': 1,
#   '青春': 1},
#  {'剧情': 1,
#   '弗朗索瓦-格扎维埃·德梅松': 1,
#   '尼古拉斯·迪佛休尔': 1,
#   '梅兰尼·蒂埃里': 1,
#   '佛洛伦丝·托马辛': 1,
#   '塞西尔·卡塞尔': 1,
#   '法国': 1,
#   'other_director': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '歌舞': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '埃里克·斯托尔兹': 1,
#   '玛丽·斯图尔特·马斯特森': 1,
#   '莉·汤普森': 1,
#   '克莱格·谢佛': 1,
#   'John': 1,
#   'other_actor': 1,
#   'John Ashton': 1,
#   '阿莉雅·布哈特': 1,
#   '沙希德·卡普尔': 1,
#   '美国': 1,
#   '霍华德·达奇': 1,
#   '经典': 1,
#   '女性': 1,
#   '青春': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '惊悚': 1,
#   '米歇尔·拉罗克': 1,
#   '法国': 1,
#   '詹姆斯·胡特': 1,
#   '经典': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '马里奥·毛瑞尔': 1,
#   '武艺': 1,
#   '叶青': 1,
#   'other_actor': 1,
#   '泰国': 1,
#   '朱少宇': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'科幻': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '动作': 1,
#   '丹尼·格洛弗': 1,
#   '加里·布塞': 1,
#   'other_actor': 1,
#   '卢宾·布雷兹': 1,
#   '玛利亚·康柯塔·阿隆索': 1,
#   '美国': 1,
#   '斯蒂芬·霍普金斯': 1,
#   '经典': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '动作': 1,
#   '剧情': 1,
#   '惊悚': 1,
#   '约瑟夫·高登-莱维特': 1,
#   '杰夫·丹尼尔斯': 1,
#   '马修·古迪': 1,
#   '艾拉·菲舍尔': 1,
#   '卡拉·古奇诺': 1,
#   '美国': 1,
#   'other_director': 1,
#   '励志': 1},
#  {'传记': 1,
#   '音乐': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '意大利': 1,
#   'other_director': 1,
#   '文艺': 1},
#  {'冒险': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '迈克尔·J·福克斯': 1,
#   '莎莉·菲尔德': 1,
#   '唐·阿米契': 1,
#   '金·格雷斯特': 1,
#   'other_actor': 1,
#   'Ed': 1,
#   '美国': 1,
#   '杜维因·邓纳姆': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '战争': 1,
#   '剧情': 1,
#   '约翰·威德伯格': 1,
#   'other_actor': 1,
#   '伯恩·谢尔曼': 1,
#   '丹麦': 1,
#   '波·维德伯格': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '安在模': 1,
#   '尹恩惠': 1,
#   '郑俊河': 1,
#   '韩国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '袁咏仪': 1,
#   '邱心志': 1,
#   '周秀娜': 1,
#   '李佳航': 1,
#   '林雪': 1,
#   '香港': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '香港': 1,
#   '江龙': 1,
#   'other_director': 1,
#   '搞笑': 1},
#  {'传记': 1, '历史': 1, 'other_actor': 1, '德国': 1, 'other_director': 1, '女性': 1},
#  {'剧情': 1, '江霞': 1, 'other_actor': 1, '台湾': 1, 'other_director': 1, '青春': 1},
#  {'喜剧': 1,
#   '奇幻': 1,
#   '戸松遥': 1,
#   'other_actor': 1,
#   '関智一': 1,
#   '日本': 1,
#   'other_director': 1,
#   '魔幻': 1,
#   '青春': 1},
#  {'恐怖': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '罗兰': 1,
#   '王合喜': 1,
#   '陈颖妍': 1,
#   'other_actor': 1,
#   '香港': 1,
#   'other_director': 1,
#   '魔幻': 1},
#  {'同性': 1,
#   '剧情': 1,
#   '托比·瑞格波': 1,
#   '马西娅·盖伊·哈登': 1,
#   '彼得·盖勒': 1,
#   '刘玉玲': 1,
#   '史蒂芬·朗': 1,
#   '意大利': 1,
#   'other_director': 1,
#   '青春': 1,
#   '励志': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '陶泽如': 1,
#   '谢园': 1,
#   '于莉': 1,
#   '中国大陆': 1,
#   '王进': 1,
#   '女性': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '三ツ矢雄二': 1,
#   '日高のり子': 1,
#   '難波圭一': 1,
#   '日本': 1,
#   '杉井仪三郎': 1,
#   '经典': 1,
#   '青春': 1},
#  {'剧情': 1,
#   '仲代达矢': 1,
#   '黑木华': 1,
#   '原田美枝子': 1,
#   '小林薰': 1,
#   '阿部宽': 1,
#   '日本': 1,
#   '小林政广': 1,
#   '文艺': 1},
#  {'科幻': 1,
#   '奇幻': 1,
#   '动作': 1,
#   'other_actor': 1,
#   '韩国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'历史': 1, '剧情': 1, '谢添': 1, '于蓝': 1, '中国大陆': 1, '水华': 1, '经典': 1},
#  {'冒险': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '马丁·弗瑞曼': 1,
#   '安东尼·海斯': 1,
#   '苏茜·波特': 1,
#   'other_actor': 1,
#   '澳大利亚': 1,
#   '本·豪林': 1,
#   '尤兰达·拉姆克': 1,
#   '感人': 1},
#  {'歌舞': 1,
#   '音乐': 1,
#   '爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '克里斯托弗·麦克唐纳': 1,
#   '艾斯-T': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '经典': 1,
#   '文艺': 1},
#  {'恐怖': 1,
#   '惊悚': 1,
#   '喜剧': 1,
#   '罗兰': 1,
#   '谭小环': 1,
#   '麦家琪': 1,
#   '香港': 1,
#   'other_director': 1,
#   '魔幻': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '路易·加瑞尔': 1,
#   '安娜·穆格拉利斯': 1,
#   'other_actor': 1,
#   '艾斯特·加瑞尔': 1,
#   '法国': 1,
#   '菲利普·加瑞尔': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '李枖原': 1,
#   '李栋旭': 1,
#   '柳承龙': 1,
#   '韩国': 1,
#   'other_director': 1,
#   '文艺': 1},
#  {'科幻': 1,
#   '冒险': 1,
#   '动作': 1,
#   '奇幻': 1,
#   '惊悚': 1,
#   'Brad Johnson': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'other_director': 1,
#   '魔幻': 1},
#  {'历史': 1,
#   '动作': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '张东健': 1,
#   '郑俊镐': 1,
#   '金相中': 1,
#   '李凡秀': 1,
#   '金仁权': 1,
#   '韩国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'科幻': 1,
#   '恐怖': 1,
#   '冒险': 1,
#   '动作': 1,
#   '石丸博也': 1,
#   'other_actor': 1,
#   '小林清志': 1,
#   '日本': 1,
#   '勝間田具治': 1,
#   '魔幻': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '纳塔莉·贝伊': 1,
#   '布鲁·欧吉尔': 1,
#   '塞缪尔·勒·比汉': 1,
#   '贾克·鲍那非': 1,
#   '奥黛丽·塔图': 1,
#   '法国': 1,
#   '托涅·马歇尔': 1,
#   '女性': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '樱庭奈奈美': 1,
#   '太贺': 1,
#   '竹富圣花': 1,
#   '冈山天音': 1,
#   '入江甚仪': 1,
#   '日本': 1,
#   '熊坂出': 1,
#   '青春': 1},
#  {'音乐': 1,
#   '爱情': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '同性': 1,
#   '剧情': 1,
#   '拉妮·玛克赫吉': 1,
#   '兰迪普·弘达': 1,
#   '纳瓦祖丁·席迪圭': 1,
#   'other_actor': 1,
#   '兰维尔·肖里': 1,
#   '印度': 1,
#   '卓娅·阿赫塔尔': 1,
#   'other_director': 1,
#   '卡伦·乔哈尔': 1,
#   '阿努拉格·卡施亚普': 1,
#   '经典': 1,
#   '励志': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '剧情': 1,
#   '崔凡特·罗兹': 1,
#   'other_actor': 1,
#   '马赫沙拉·阿里': 1,
#   '娜奥米·哈里斯': 1,
#   '加奈儿·梦奈': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'剧情': 1,
#   '保罗·纽曼': 1,
#   '英国': 1,
#   'other_director': 1,
#   '感人': 1,
#   '经典': 1,
#   '励志': 1},
#  {'爱情': 1,
#   '犯罪': 1,
#   '喜剧': 1,
#   '动作': 1,
#   'other_actor': 1,
#   '中国大陆': 1,
#   '陈宇': 1,
#   'other_director': 1,
#   '黑帮': 1},
#  {'悬疑': 1,
#   '冒险': 1,
#   '奇幻': 1,
#   '剧情': 1,
#   '本·克劳斯': 1,
#   '彼得·威勒': 1,
#   '马洛可·伯尼尼': 1,
#   '意大利': 1,
#   '阿尔贝托·内格林': 1,
#   '魔幻': 1},
#  {'爱情': 1,
#   '科幻': 1,
#   '喜剧': 1,
#   '情色': 1,
#   '奇幻': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '搞笑': 1},
#  {'传记': 1,
#   'other_actor': 1,
#   '张艾嘉': 1,
#   '王家卫': 1,
#   '侯孝贤': 1,
#   '台湾': 1,
#   '关本良': 1,
#   '姜秀琼': 1,
#   '文艺': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '派珀·劳瑞': 1,
#   '茜茜·斯派塞克': 1,
#   '爱德华·福隆': 1,
#   '沃尔特·马修': 1,
#   '美国': 1,
#   '查尔斯·马修': 1,
#   '文艺': 1},
#  {'科幻': 1,
#   '冒险': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '克里斯·帕拉特': 1,
#   '威尔·法瑞尔': 1,
#   '伊丽莎白·班克斯': 1,
#   '威尔·阿奈特': 1,
#   '连姆·尼森': 1,
#   '丹麦': 1,
#   '菲尔·罗德': 1,
#   '克里斯托弗·米勒': 1,
#   '励志': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '克里斯汀·斯图尔特': 1,
#   '杰西·巴托克': 1,
#   'other_actor': 1,
#   '亚伦·斯坦福': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '奇幻': 1,
#   '剧情': 1,
#   '张榕容': 1,
#   '庹宗华': 1,
#   '黄健玮': 1,
#   '台湾': 1,
#   '郑有杰': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '动作': 1,
#   '犯罪': 1,
#   '剧情': 1,
#   '郑伊健': 1,
#   '吴倩莲': 1,
#   '葛民辉': 1,
#   '朱咪咪': 1,
#   'other_actor': 1,
#   '香港': 1,
#   '刘伟强': 1,
#   '黑帮': 1},
#  {'科幻': 1,
#   '喜剧': 1,
#   '冒险': 1,
#   '动作': 1,
#   '剧情': 1,
#   '灾难': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '大泉洋': 1,
#   '有村架纯': 1,
#   '长泽雅美': 1,
#   '吉泽悠': 1,
#   '冈田义德': 1,
#   '日本': 1,
#   '佐藤信介': 1,
#   '搞笑': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '迈克尔·比奇': 1,
#   'other_actor': 1,
#   '布瑞特·凯利': 1,
#   '加拿大': 1,
#   'other_director': 1,
#   '青春': 1,
#   '励志': 1,
#   '搞笑': 1},
#  {'犯罪': 1,
#   '歌舞': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '帕丽莱蒂·曹帕拉': 1,
#   '阿贾耶·德乌干': 1,
#   'other_actor': 1,
#   '库纳尔·赫姆': 1,
#   '印度': 1,
#   '罗希特·谢迪': 1,
#   '青春': 1,
#   '搞笑': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '詹姆斯·斯图尔特': 1,
#   '丽·莱米克': 1,
#   '本·戈扎那': 1,
#   '阿瑟·奥康纳': 1,
#   'other_actor': 1,
#   '美国': 1,
#   '奥托·普雷明格': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '音乐': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '德国': 1,
#   'Sven J': 1,
#   'Matten': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '犯罪': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '郝蕾': 1,
#   '秦昊': 1,
#   '齐溪': 1,
#   '朱亚文': 1,
#   '祖锋': 1,
#   '法国': 1,
#   '娄烨': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '三ツ矢雄二': 1,
#   '日高のり子': 1,
#   '難波圭一': 1,
#   '日本': 1,
#   '杉井仪三郎': 1,
#   '经典': 1,
#   '青春': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '彼得·塞勒斯': 1,
#   '雪莉·麦克雷恩': 1,
#   '茂文·道格拉斯': 1,
#   '杰克·瓦尔登': 1,
#   '理查德·贝斯哈特': 1,
#   '美国': 1,
#   '哈尔·阿什贝': 1,
#   '经典': 1},
#  {'传记': 1, 'other_actor': 1, '法国': 1, 'other_director': 1, '感人': 1},
#  {'剧情': 1,
#   '尤里·雅科夫列夫': 1,
#   'other_actor': 1,
#   '俄罗斯': 1,
#   'other_director': 1,
#   '经典': 1,
#   '文艺': 1},
#  {'剧情': 1,
#   '柳乐优弥': 1,
#   '北浦爱': 1,
#   'other_actor': 1,
#   '韩英惠': 1,
#   '日本': 1,
#   '是枝裕和': 1,
#   '感人': 1,
#   '经典': 1,
#   '文艺': 1,
#   '青春': 1},
#  {'音乐': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '汉娜·赫茨施普龙': 1,
#   '里奇·穆勒': 1,
#   '德国': 1,
#   'other_director': 1,
#   '励志': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'科幻': 1,
#   '悬疑': 1,
#   '奇幻': 1,
#   '剧情': 1,
#   '马蒂娜·格德克': 1,
#   'other_actor': 1,
#   '德国': 1,
#   'other_director': 1,
#   '文艺': 1},
#  {'爱情': 1, '情色': 1, '剧情': 1, '金瑞亨': 1, '韩国': 1, 'other_director': 1, '文艺': 1},
#  {'科幻': 1,
#   '动作': 1,
#   '奇幻': 1,
#   '恐怖': 1,
#   '战争': 1,
#   '惊悚': 1,
#   '布莱恩·拉金': 1,
#   'other_actor': 1,
#   '本·兰伯特': 1,
#   '英国': 1,
#   'other_director': 1,
#   '魔幻': 1},
#  {'爱情': 1,
#   '战争': 1,
#   '剧情': 1,
#   '凯瑟琳·德纳芙': 1,
#   '艾曼纽·贝阿': 1,
#   '文森特·佩雷斯': 1,
#   '约翰·马尔科维奇': 1,
#   '帕斯卡尔·格雷戈里': 1,
#   '意大利': 1,
#   '拉乌·鲁兹': 1,
#   '文艺': 1},
#  {'犯罪': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '罗杰·阿拉姆': 1,
#   'other_actor': 1,
#   '威廉·鲁尼': 1,
#   '意大利': 1,
#   '肯·洛奇': 1,
#   '青春': 1,
#   '励志': 1},
#  {'剧情': 1, '玛利亚·霍夫斯塔尔': 1, 'other_actor': 1, '德国': 1, '尤里西·塞德尔': 1, '文艺': 1},
#  {'犯罪': 1,
#   '情色': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '碧姬·芭铎': 1,
#   '意大利': 1,
#   '罗杰·瓦迪姆': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '犯罪': 1,
#   '情色': 1,
#   '动作': 1,
#   '片冈礼子': 1,
#   'other_actor': 1,
#   '鹤见辰吾': 1,
#   '日本': 1,
#   'other_director': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '渥美清': 1,
#   '倍赏千惠子': 1,
#   '香川京子': 1,
#   '日本': 1,
#   '山田洋次': 1,
#   '经典': 1},
#  {'犯罪': 1,
#   '爱情': 1,
#   '科幻': 1,
#   '悬疑': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '惊悚': 1,
#   '伊莎贝尔·于佩尔': 1,
#   '罗兰·拉斐特': 1,
#   '安妮·康斯金尼': 1,
#   '夏尔·贝尔林': 1,
#   '维尔日妮·埃菲拉': 1,
#   '杰昆·菲尼克斯': 1,
#   '斯嘉丽·约翰逊': 1,
#   '艾米·亚当斯': 1,
#   '鲁妮·玛拉': 1,
#   '奥利维亚·王尔德': 1,
#   '美国': 1,
#   '斯派克·琼斯': 1,
#   '感人': 1,
#   '经典': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'传记': 1, '剧情': 1, 'other_actor': 1, '德国': 1, 'other_director': 1, '文艺': 1},
#  {'爱情': 1,
#   '历史': 1,
#   '犯罪': 1,
#   '动作': 1,
#   '胡军': 1,
#   '余男': 1,
#   '凤小岳': 1,
#   '秦昊': 1,
#   '李梦': 1,
#   '中国大陆': 1,
#   '胡雪桦': 1,
#   '女性': 1},
#  {'喜剧': 1,
#   '袁洁莹': 1,
#   '钟镇涛': 1,
#   '吕颂贤': 1,
#   '李蕙敏': 1,
#   'other_actor': 1,
#   '香港': 1,
#   '钟澍佳': 1,
#   '搞笑': 1},
#  {'同性': 1,
#   '悬疑': 1,
#   '情色': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '中国大陆': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '曼迪·摩尔': 1,
#   '特伦特·福特': 1,
#   '艾莉森·珍妮': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'爱情': 1, 'other_actor': 1, '泰国': 1, 'Kittikorn Liasirikun': 1, '青春': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '雷·米兰德': 1,
#   '简·怀曼': 1,
#   '菲利普·特里': 1,
#   'other_actor': 1,
#   '美国': 1,
#   '比利·怀德': 1,
#   '经典': 1},
#  {'喜剧': 1, 'other_actor': 1, '美国': 1, 'other_director': 1, '青春': 1},
#  {'剧情': 1,
#   '竹野内丰': 1,
#   '江口洋介': 1,
#   '松坂桃李': 1,
#   '优香': 1,
#   '小池荣子': 1,
#   '日本': 1,
#   'other_director': 1,
#   '感人': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '同性': 1,
#   '剧情': 1,
#   '原田芳雄': 1,
#   '樋口可南子': 1,
#   'other_actor': 1,
#   '日本': 1,
#   'other_director': 1,
#   '女性': 1},
#  {'歌舞': 1,
#   '音乐': 1,
#   '爱情': 1,
#   '传记': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '亚历山大·佩特罗夫': 1,
#   '玛丽亚·阿龙诺娃': 1,
#   '俄罗斯': 1,
#   'other_director': 1,
#   '励志': 1,
#   '女性': 1},
#  {'剧情': 1,
#   '凯文·克莱恩': 1,
#   '琼·艾伦': 1,
#   '西格妮·韦弗': 1,
#   '亨利·科泽尼': 1,
#   '托比·马奎尔': 1,
#   '法国': 1,
#   '李安': 1,
#   '经典': 1,
#   '文艺': 1,
#   '青春': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '朱塞佩·巴蒂斯通': 1,
#   '安德里亚·博斯卡': 1,
#   '安妮塔·卡皮奥尼': 1,
#   '意大利': 1,
#   'other_director': 1,
#   '经典': 1,
#   '励志': 1,
#   '青春': 1},
#  {'犯罪': 1,
#   '动作': 1,
#   '剧情': 1,
#   '郑伊健': 1,
#   '莫文蔚': 1,
#   '李彩桦': 1,
#   '黄品源': 1,
#   '吕颂贤': 1,
#   '香港': 1,
#   '马楚成': 1,
#   '黑帮': 1},
#  {'犯罪': 1,
#   '动作': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '杜夫·龙格尔': 1,
#   '维尼·琼斯': 1,
#   '比利·赞恩': 1,
#   '罗伯特·戴维': 1,
#   '罗伯特·米亚诺': 1,
#   '美国': 1,
#   'other_director': 1,
#   '经典': 1,
#   '黑帮': 1},
#  {'情色': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '英国': 1,
#   'other_director': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '动作': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '巴斯特·基顿': 1,
#   'T': 1,
#   'other_actor': 1,
#   '美国': 1,
#   '经典': 1},
#  {'惊悚': 1,
#   '剧情': 1,
#   '柳德焕': 1,
#   '南相美': 1,
#   '曹承佑': 1,
#   '韩国': 1,
#   '具惠善': 1,
#   '感人': 1,
#   '文艺': 1},
#  {'喜剧': 1,
#   '周星驰': 1,
#   '梅艳芳': 1,
#   '陈百祥': 1,
#   '周海媚': 1,
#   '梁家仁': 1,
#   '香港': 1,
#   '王晶': 1,
#   '搞笑': 1},
#  {'动作': 1,
#   '武侠': 1,
#   '剧情': 1,
#   '李连杰': 1,
#   '关之琳': 1,
#   '莫少聪': 1,
#   '熊欣欣': 1,
#   '刘洵': 1,
#   '香港': 1,
#   '徐克': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '剧情': 1,
#   '栩原乐人': 1,
#   'other_actor': 1,
#   '日本': 1,
#   '清水厚': 1,
#   '青春': 1},
#  {'武侠': 1,
#   '喜剧': 1,
#   '奇幻': 1,
#   '动作': 1,
#   '甄子丹': 1,
#   '王宝强': 1,
#   '黄圣依': 1,
#   '任达华': 1,
#   'other_actor': 1,
#   '中国大陆': 1,
#   '罗永昌': 1,
#   '魔幻': 1,
#   '搞笑': 1},
#  {'奇幻': 1,
#   '剧情': 1,
#   '恰拉': 1,
#   '浅野忠信': 1,
#   'other_actor': 1,
#   '六平直政': 1,
#   '日本': 1,
#   '岩井俊二': 1,
#   '经典': 1,
#   '文艺': 1,
#   '青春': 1},
#  {'剧情': 1,
#   '比莉·派佩': 1,
#   '布伦丹·考威尔': 1,
#   'other_actor': 1,
#   '英国': 1,
#   '西蒙·斯通': 1,
#   '女性': 1},
#  {'音乐': 1, 'other_actor': 1, '英国': 1, '迪恩·德布洛斯': 1, '文艺': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '米契尔·哈思曼': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'同性': 1, '剧情': 1, 'other_actor': 1, '美国': 1, 'other_director': 1, '女性': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '贝蒂·戴维斯': 1,
#   '查尔斯·博耶': 1,
#   '杰弗瑞·林恩': 1,
#   '美国': 1,
#   '安纳托尔·李维克': 1,
#   '经典': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '惊悚': 1,
#   '恐怖': 1,
#   'other_actor': 1,
#   'D': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '搞笑': 1},
#  {'剧情': 1, 'other_actor': 1, '中国大陆': 1, 'other_director': 1, '文艺': 1},
#  {'科幻': 1,
#   '悬疑': 1,
#   '冒险': 1,
#   '动作': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '彼得·麦考利': 1,
#   '威廉·德芙里': 1,
#   'William': 1,
#   'other_actor': 1,
#   '美国': 1,
#   '理查德·富兰克林': 1,
#   '魔幻': 1,
#   '经典': 1},
#  {'剧情': 1,
#   'Dharmendra': 1,
#   'other_actor': 1,
#   '印度': 1,
#   'Yash Chopra': 1,
#   '经典': 1},
#  {'犯罪': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '玛莉卡·格林': 1,
#   '法国': 1,
#   '罗伯特·布列松': 1,
#   '经典': 1},
#  {'动作': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '乔什·哈切森': 1,
#   '布鲁斯·格林伍德': 1,
#   '比尔·努恩': 1,
#   'Scotch Ellis Loring': 1,
#   'other_actor': 1,
#   '加拿大': 1,
#   'other_director': 1,
#   '搞笑': 1},
#  {'爱情': 1, '剧情': 1, 'other_actor': 1, '意大利': 1, '奥塔·埃索里亚尼': 1, '文艺': 1},
#  {'犯罪': 1,
#   '科幻': 1,
#   '悬疑': 1,
#   '冒险': 1,
#   '动作': 1,
#   '剧情': 1,
#   '灾难': 1,
#   '奇幻': 1,
#   '恐怖': 1,
#   '战争': 1,
#   '惊悚': 1,
#   '克莱恩·克劳福德': 1,
#   '艾米莉·莫迪默': 1,
#   '詹姆斯·戴尔': 1,
#   '马克斯·马蒂尼': 1,
#   '布鲁斯·格林伍德': 1,
#   '美国': 1,
#   'other_director': 1,
#   '搞笑': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '约翰·克立斯': 1,
#   '特洛耶·希文': 1,
#   'other_actor': 1,
#   '詹森·库伯': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '科幻': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '苏卡达·顾珑希': 1,
#   'other_actor': 1,
#   '朋抔·里拉塔纳卡邹': 1,
#   '泰国': 1,
#   '查亚诺普·布恩帕拉科布': 1,
#   '青春': 1,
#   '文艺': 1,
#   '搞笑': 1},
#  {'歌舞': 1,
#   'other_actor': 1,
#   'Adam T': 1,
#   'Brooks': 1,
#   'Brooklyn Sudano': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '励志': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '娜塔莉·普莱斯': 1,
#   '艾米莉·布朗特': 1,
#   '帕迪·康斯戴恩': 1,
#   '英国': 1,
#   '帕维乌·帕夫利科夫斯基': 1,
#   '青春': 1,
#   '女性': 1},
#  {'战争': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '奥萝尔·克莱芒': 1,
#   '特蕾泽·吉泽': 1,
#   '意大利': 1,
#   '路易·马勒': 1,
#   '青春': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '蒂埃里·莱尔米特': 1,
#   '拉斐尔·佩尔索纳': 1,
#   '尼尔斯·阿贺斯图普': 1,
#   '朱莉·加耶': 1,
#   '阿娜伊斯·德穆斯蒂埃': 1,
#   '法国': 1,
#   '贝特朗·塔维涅': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '奉太奎': 1,
#   '郑丽媛': 1,
#   '金太贤': 1,
#   '韩国': 1,
#   '李石勋': 1,
#   '青春': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '战争': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '安德里亚·迪·斯戴法诺': 1,
#   '米莱姆·里昂': 1,
#   '文森特·里奥特': 1,
#   '意大利': 1,
#   '皮弗': 1,
#   '黑帮': 1},
#  {'爱情': 1,
#   '传记': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '科斯蒂亚·乌尔曼': 1,
#   '雅各布·马琛茨': 1,
#   '安娜·玛丽亚·穆埃': 1,
#   '约翰·冯·比罗': 1,
#   '杰拉德·亚历山大·海德': 1,
#   '德国': 1,
#   '马克·罗特蒙德': 1,
#   '励志': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '剧情': 1,
#   'Brigitte Lahaie': 1,
#   'other_actor': 1,
#   '法国': 1,
#   'other_director': 1,
#   '经典': 1},
#  {'传记': 1,
#   '历史': 1,
#   '战争': 1,
#   '剧情': 1,
#   '蔡振南': 1,
#   'other_actor': 1,
#   '李天禄': 1,
#   '林强': 1,
#   '杨丽音': 1,
#   '台湾': 1,
#   '侯孝贤': 1,
#   '文艺': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '历苏': 1,
#   '美国': 1,
#   '加美·尤伊斯': 1,
#   '经典': 1,
#   '搞笑': 1},
#  {'奇幻': 1, 'other_actor': 1, '加拿大': 1, 'other_director': 1, '经典': 1, '文艺': 1},
#  {'科幻': 1,
#   '悬疑': 1,
#   '动作': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '艾米莉·布朗宁': 1,
#   '杰米·钟': 1,
#   '吉娜·马隆': 1,
#   '凡妮莎·哈金斯': 1,
#   '艾比·考尼什': 1,
#   '美国': 1,
#   '扎克·施奈德': 1,
#   '魔幻': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '奇幻': 1,
#   '剧情': 1,
#   '逢坂良太': 1,
#   '野水伊织': 1,
#   '寺岛拓笃': 1,
#   '斋藤千和': 1,
#   '木村良平': 1,
#   '日本': 1,
#   '宮繁之': 1,
#   '魔幻': 1},
#  {'传记': 1, '历史': 1, '剧情': 1, '朱莉娅·奥蒙德': 1, '俄罗斯': 1, '迈克尔·安德森': 1, '女性': 1},
#  {'剧情': 1,
#   '向井理': 1,
#   '松坂桃李': 1,
#   '柄本佑': 1,
#   '洼田正孝': 1,
#   '村川绘梨': 1,
#   '日本': 1,
#   '深作健太': 1,
#   '青春': 1,
#   '励志': 1},
#  {'剧情': 1, '文森特·拉科斯特': 1, '雅克·冈布兰': 1, '法国': 1, 'other_director': 1, '青春': 1},
#  {'惊悚': 1,
#   '奇幻': 1,
#   'other_actor': 1,
#   '澳大利亚': 1,
#   'other_director': 1,
#   '青春': 1,
#   '励志': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '法国': 1,
#   'other_director': 1,
#   '经典': 1,
#   '文艺': 1},
#  {'剧情': 1, 'other_actor': 1, '王杰': 1, '中国大陆': 1, '应亮': 1, '青春': 1, '文艺': 1},
#  {'犯罪': 1,
#   '爱情': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '剧情': 1,
#   '惊悚': 1,
#   '阿什顿·库彻': 1,
#   '凯瑟琳·海格尔': 1,
#   '汤姆·塞立克': 1,
#   '凯瑟琳·欧哈拉': 1,
#   '凯瑟琳·温妮克': 1,
#   '美国': 1,
#   'other_director': 1,
#   '搞笑': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '安德烈·维尔姆斯': 1,
#   '卡蒂·奥廷宁': 1,
#   '让-皮埃尔·达鲁森': 1,
#   'other_actor': 1,
#   '叶琳娜·萨罗': 1,
#   '德国': 1,
#   '阿基·考里斯马基': 1,
#   '感人': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '音乐': 1,
#   '文塔瓦·史蓝蓬': 1,
#   'other_actor': 1,
#   '楚缇玛·提潘娜特': 1,
#   '泰国': 1,
#   '尼提瓦·塔拉吞': 1,
#   '青春': 1,
#   '励志': 1,
#   '文艺': 1},
#  {'剧情': 1, 'Li': 1, 'other_actor': 1, '中国大陆': 1, '杨恒': 1, '青春': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '坎德拉·佩尼亚': 1,
#   'other_actor': 1,
#   '西班牙': 1,
#   'other_director': 1,
#   '女性': 1},
#  {'科幻': 1,
#   '喜剧': 1,
#   '奇幻': 1,
#   '让·雷诺': 1,
#   '克里斯蒂昂·克拉维埃': 1,
#   'Muriel Robin': 1,
#   '法国': 1,
#   '让-玛丽·普瓦雷': 1,
#   '魔幻': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '剧情': 1,
#   '平川大辅': 1,
#   '河原木志穗': 1,
#   '日本': 1,
#   '元永庆太郎': 1,
#   '青春': 1,
#   '搞笑': 1},
#  {'恐怖': 1, '惊悚': 1, 'other_actor': 1, '法国': 1, '让·洛林': 1, '魔幻': 1},
#  {'犯罪': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '丹尼尔·尼科莱特': 1,
#   '米西·派勒': 1,
#   '蒂姆·布雷克·尼尔森': 1,
#   'other_actor': 1,
#   '萨西尔·扎玛塔': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '阿拉斯塔尔·西姆': 1,
#   'other_actor': 1,
#   '英国': 1,
#   '盖伊·汉弥尔顿': 1,
#   '经典': 1},
#  {'战争': 1, '剧情': 1, '李维康': 1, '高玉倩': 1, '中国大陆': 1, '崔嵬': 1, '陈怀皑': 1, '经典': 1},
#  {'剧情': 1, 'other_actor': 1, '法国': 1, 'other_director': 1, '女性': 1, '文艺': 1},
#  {'爱情': 1, '奇幻': 1, '剧情': 1, '井上喜久子': 1, '日本': 1, '合田浩章': 1, '魔幻': 1},
#  {'冒险': 1,
#   '战争': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '让-保罗·贝尔蒙多': 1,
#   '玛丽-弗朗丝·皮西尔': 1,
#   'other_actor': 1,
#   '德国': 1,
#   '热拉尔·乌里': 1,
#   '经典': 1,
#   '搞笑': 1},
#  {'冒险': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '加拿大': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'犯罪': 1,
#   '爱情': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '惊悚': 1,
#   'other_actor': 1,
#   '爱德华·诺顿': 1,
#   '保罗·吉亚玛提': 1,
#   '杰西卡·贝尔': 1,
#   '卢夫斯·塞维尔': 1,
#   '埃迪·马森': 1,
#   '美国': 1,
#   '尼尔·博格': 1,
#   '魔幻': 1,
#   '经典': 1,
#   '文艺': 1,
#   '感人': 1},
#  {'爱情': 1,
#   '悬疑': 1,
#   '惊悚': 1,
#   '恐怖': 1,
#   '娜塔莎·金斯基': 1,
#   '理查德·威德马克': 1,
#   '克里斯托弗·李': 1,
#   '德国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'犯罪': 1,
#   '爱情': 1,
#   '传记': 1,
#   '历史': 1,
#   '剧情': 1,
#   '马克·鲁弗洛': 1,
#   '迈克尔·基顿': 1,
#   '瑞秋·麦克亚当斯': 1,
#   '列维·施瑞博尔': 1,
#   '约翰·斯拉特里': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'other_director': 1,
#   '经典': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '有村架纯': 1,
#   '工藤阿须加': 1,
#   '渊上泰史': 1,
#   '村上虹郎': 1,
#   '中村优子': 1,
#   '日本': 1,
#   '广木隆一': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'剧情': 1,
#   '赖雅妍': 1,
#   '吴中天': 1,
#   '李冠毅': 1,
#   '莫子仪': 1,
#   '吴慷仁': 1,
#   '台湾': 1,
#   '郑芬芬': 1,
#   '钮承泽': 1,
#   '程孝泽': 1,
#   '李启源': 1,
#   '陈映蓉': 1,
#   'other_director': 1,
#   '李康生': 1,
#   '文艺': 1},
#  {'犯罪': 1,
#   '冒险': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '剧情': 1,
#   '丹尼斯·霍珀': 1,
#   '基弗·萨瑟兰': 1,
#   '卡罗尔·凯恩': 1,
#   '美国': 1,
#   '弗兰克·阿穆里': 1,
#   '感人': 1},
#  {'音乐': 1, '安德烈·波切利': 1, '意大利': 1, 'other_director': 1, '经典': 1, '文艺': 1},
#  {'歌舞': 1,
#   '音乐': 1,
#   '爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '查理·卓别林': 1,
#   '巴斯特·基顿': 1,
#   '克莱尔·布鲁姆': 1,
#   '尼格尔·布鲁斯': 1,
#   'other_actor': 1,
#   '英国': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '武侠': 1,
#   '奇幻': 1,
#   '徐洁儿': 1,
#   '袁晓超': 1,
#   '刘承俊': 1,
#   'other_actor': 1,
#   '香港': 1,
#   '苗述': 1,
#   '魔幻': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '佐佐木希': 1,
#   '谷原章介': 1,
#   '山本光': 1,
#   'other_actor': 1,
#   '日本': 1,
#   'other_director': 1,
#   '感人': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'科幻': 1,
#   '冒险': 1,
#   '奇幻': 1,
#   '野泽雅子': 1,
#   '池田昌子': 1,
#   '麻上洋子': 1,
#   '藤田淑子': 1,
#   '银河万丈': 1,
#   '日本': 1,
#   '林太郎': 1,
#   '经典': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   'Marco Giallini': 1,
#   'other_actor': 1,
#   '意大利': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '犯罪': 1,
#   '音乐': 1,
#   '剧情': 1,
#   '广濑爱丽丝': 1,
#   '古畑星夏': 1,
#   '古川雄辉': 1,
#   '平冈佑太': 1,
#   '朝美穗香': 1,
#   'Angelina Jolie': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'other_director': 1,
#   '感人': 1,
#   '青春': 1},
#  {'情色': 1,
# ...
#   '剧情': 1,
#   'other_actor': 1,
#   '加拿大': 1,
#   'other_director': 1,
#   '励志': 1},
#  {'歌舞': 1,
#   '音乐': 1,
#   '爱情': 1,
#   '情色': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '普拉西多·多明戈': 1,
#   '帕斯·贝加': 1,
#   '莱昂纳多·斯巴拉格利亚': 1,
#   '丽塔·海华斯': 1,
#   '格伦·福特': 1,
#   'Plácido Domingo': 1,
#   '西班牙': 1,
#   '弗朗西斯科·罗西': 1,
#   '经典': 1,
#   '女性': 1,
#   '文艺': 1,
#   '青春': 1},
#  {'音乐': 1, 'other_actor': 1, '中国大陆': 1, 'other_director': 1, '经典': 1},
#  {'剧情': 1,
#   '阿尔法·伍达德': 1,
#   '茜茜·斯派塞克': 1,
#   '祖蒂·弗兰': 1,
#   '里奇·卡尼佩': 1,
#   '美国': 1,
#   '托尼·比尔': 1,
#   '感人': 1},
#  {'武侠': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '王紫潼': 1,
#   '中国大陆': 1,
#   'other_director': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '奇幻': 1,
#   '剧情': 1,
#   '裴斗娜': 1,
#   '井浦新': 1,
#   '板尾创路': 1,
#   '余贵美子': 1,
#   '岩松了': 1,
#   '日本': 1,
#   '是枝裕和': 1,
#   '文艺': 1},
#  {'犯罪': 1,
#   '爱情': 1,
#   '传记': 1,
#   '悬疑': 1,
#   '动作': 1,
#   '剧情': 1,
#   '历史': 1,
#   '惊悚': 1,
#   '科林·法瑞尔': 1,
#   '考莉安卡·基尔彻': 1,
#   '克里斯蒂安·贝尔': 1,
#   '克里斯托弗·普卢默': 1,
#   '奥古斯特·斯彻伦伯格': 1,
#   '李政宰': 1,
#   '崔岷植': 1,
#   '黄政民': 1,
#   '宋智孝': 1,
#   '朴圣雄': 1,
#   '韩国': 1,
#   '朴勋政': 1,
#   '经典': 1,
#   '黑帮': 1,
#   '文艺': 1},
#  {'犯罪': 1,
#   '西部': 1,
#   '动作': 1,
#   '剧情': 1,
#   '罗素·克劳': 1,
#   '克里斯蒂安·贝尔': 1,
#   '罗根·勒曼': 1,
#   '达拉斯·罗伯特斯': 1,
#   '本·福斯特': 1,
#   '美国': 1,
#   '詹姆斯·曼高德': 1,
#   '经典': 1},
#  {'犯罪': 1,
#   '动作': 1,
#   '传记': 1,
#   '剧情': 1,
#   '刘青云': 1,
#   '林家栋': 1,
#   '古天乐': 1,
#   '张晋': 1,
#   '江一燕': 1,
#   '香港': 1,
#   '刘国昌': 1,
#   '黑帮': 1},
#  {'冒险': 1,
#   '动作': 1,
#   '剧情': 1,
#   '灾难': 1,
#   '惊悚': 1,
#   '克里斯·奥唐纳': 1,
#   '罗宾·汤尼': 1,
#   '尼古拉斯·李': 1,
#   '斯科特·格伦': 1,
#   '伊沙贝拉·斯科鲁普科': 1,
#   '德国': 1,
#   '马丁·坎贝尔': 1,
#   '经典': 1,
#   '励志': 1},
#  {'传记': 1,
#   '历史': 1,
#   '剧情': 1,
#   '丹泽尔·华盛顿': 1,
#   '内特·派克': 1,
#   '朱尼·斯莫利特': 1,
#   'other_actor': 1,
#   '杰梅因·威廉姆斯': 1,
#   '美国': 1,
#   '经典': 1,
#   '励志': 1},
#  {'犯罪': 1,
#   '爱情': 1,
#   '科幻': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   'other_actor': 1,
#   '佩顿·李斯特': 1,
#   '莉亚·玛瑞·约翰逊': 1,
#   '瑞恩·纽曼': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'传记': 1,
#   '剧情': 1,
#   '科洛·莫瑞兹': 1,
#   '托马斯·曼': 1,
#   '理查德·阿米蒂奇': 1,
#   '凯瑞-安·莫斯': 1,
#   '珍妮·斯蕾特': 1,
#   '爱尔兰': 1,
#   'other_director': 1,
#   '经典': 1},
#  {'犯罪': 1,
#   '动作': 1,
#   '情色': 1,
#   '剧情': 1,
#   '惊悚': 1,
#   '西尔维斯特·史泰龙': 1,
#   '莎朗·斯通': 1,
#   '詹姆斯·伍兹': 1,
#   '罗德·斯泰格尔': 1,
#   '美国': 1,
#   'other_director': 1,
#   '经典': 1},
#  {'战争': 1, '剧情': 1, 'other_actor': 1, '法国': 1, 'other_director': 1, '女性': 1},
#  {'传记': 1,
#   '历史': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '惊悚': 1,
#   '安娜·弗莱尔': 1,
#   '卡瑞尔·罗登': 1,
#   '文森特·里根': 1,
#   'other_actor': 1,
#   '英国': 1,
#   '朱拉·亚库比斯克': 1,
#   '女性': 1},
#  {'犯罪': 1,
#   '爱情': 1,
#   '动作': 1,
#   '剧情': 1,
#   '惊悚': 1,
#   '莉顿·梅斯特': 1,
#   '托比·琼斯': 1,
#   '本·巴恩斯': 1,
#   '哈威·凯特尔': 1,
#   '肯尼·沃莫尔德 ': 1,
#   '美国': 1,
#   'other_director': 1,
#   '黑帮': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '三船敏郎': 1,
#   '志村乔': 1,
#   'other_actor': 1,
#   '千石规子': 1,
#   '渡哲也': 1,
#   '芦田伸介': 1,
#   '松坂庆子': 1,
#   '志垣太郎': 1,
#   '日本': 1,
#   '森崎东': 1,
#   '经典': 1},
#  {'同性': 1, '剧情': 1, 'other_actor': 1, '伊朗': 1, 'other_director': 1, '青春': 1},
#  {'悬疑': 1, '喜剧': 1, '剧情': 1, 'other_actor': 1, '加拿大': 1, '肖恩·加里蒂': 1, '经典': 1},
#  {'冒险': 1,
#   '喜剧': 1,
#   '奇幻': 1,
#   '朱莉娅·罗伯茨': 1,
#   '尼古拉斯·凯奇': 1,
#   '梅丽尔·斯特里普': 1,
#   '保罗·吉亚玛提': 1,
#   '美国': 1,
#   'other_director': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '卢·泰勒·普奇': 1,
#   '赛斯·格林': 1,
#   '克里斯汀·鲍尔': 1,
#   '美国': 1,
#   'other_director': 1,
#   '励志': 1,
#   '文艺': 1},
#  {'冒险': 1,
#   '喜剧': 1,
#   '奇幻': 1,
#   '克里斯蒂昂·克拉维埃': 1,
#   '热拉尔·德帕迪约': 1,
#   '罗伯托·贝尼尼': 1,
#   '意大利': 1,
#   '克洛德·齐迪': 1,
#   '魔幻': 1,
#   '搞笑': 1},
#  {'爱情': 1, '剧情': 1, '小山田小百合': 1, '本乡奏多': 1, '日本': 1, '小出正雪': 1, '文艺': 1},
#  {'犯罪': 1,
#   '动作': 1,
#   '钱小豪': 1,
#   '雷宇扬': 1,
#   '香港': 1,
#   '李钊': 1,
#   'other_director': 1,
#   '经典': 1,
#   '黑帮': 1},
#  {'科幻': 1,
#   '动作': 1,
#   '剧情': 1,
#   '休·杰克曼': 1,
#   '达科塔·高尤': 1,
#   '凯文·杜兰': 1,
#   '安东尼·麦凯': 1,
#   '伊万杰琳·莉莉': 1,
#   '印度': 1,
#   '肖恩·利维': 1,
#   '感人': 1,
#   '励志': 1},
#  {'冒险': 1,
#   '科幻': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '萨姆·亨廷顿': 1,
#   '克里斯·马奎特': 1,
#   '丹·福勒': 1,
#   '杰伊·巴鲁切尔': 1,
#   '克里斯汀·贝尔': 1,
#   '美国': 1,
#   '凯尔·纽曼': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '音乐': 1,
#   '剧情': 1,
#   '杰夫·布里吉斯': 1,
#   '米歇尔·菲佛': 1,
#   '博·布里奇斯': 1,
#   'other_actor': 1,
#   '山德·贝克利': 1,
#   '美国': 1,
#   'other_director': 1,
#   '经典': 1,
#   '文艺': 1},
#  {'喜剧': 1, '歌蒂·韩': 1, '罗宾·莱弗里': 1, '斯薇兹·昆茨': 1, '美国': 1, '迈克尔·里奇': 1, '青春': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '白客': 1,
#   '蓝盈莹': 1,
#   'other_actor': 1,
#   '周楚濋': 1,
#   '曹骏': 1,
#   '中国大陆': 1,
#   '顾长卫': 1,
#   '青春': 1,
#   '文艺': 1,
#   '搞笑': 1},
#  {'剧情': 1, 'other_actor': 1, '瑞典': 1, 'other_director': 1, '青春': 1},
#  {'科幻': 1,
#   '冒险': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '奇幻': 1,
#   '惊悚': 1,
#   '梅丽莎·麦卡西': 1,
#   '克里斯汀·韦格': 1,
#   '凯特·麦克金农': 1,
#   'other_actor': 1,
#   '克里斯·海姆斯沃斯': 1,
#   '美国': 1,
#   '保罗·费格': 1,
#   '魔幻': 1,
#   '女性': 1,
#   '搞笑': 1},
#  {'爱情': 1, '剧情': 1, '安迪·吉雷': 1, '塞西尔·卡塞尔': 1, '西班牙': 1, '埃里克·侯麦': 1, '文艺': 1},
#  {'剧情': 1,
#   '米歇尔·菲佛': 1,
#   '蕾妮·齐薇格': 1,
#   '艾莉森·洛曼': 1,
#   '罗宾·怀特': 1,
#   '德国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'科幻': 1,
#   '悬疑': 1,
#   '动作': 1,
#   '剧情': 1,
#   '灾难': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '西格妮·韦弗': 1,
#   '汤姆·斯凯里特': 1,
#   '维罗尼卡·卡维特': 1,
#   '哈利·戴恩·斯坦通': 1,
#   '约翰·赫特': 1,
#   '英国': 1,
#   '雷德利·斯科特': 1,
#   '经典': 1},
#  {'传记': 1,
#   '历史': 1,
#   '战争': 1,
#   '剧情': 1,
#   '姜河那': 1,
#   '朴正民': 1,
#   '韩国': 1,
#   '李濬益': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'科幻': 1,
#   '悬疑': 1,
#   '冒险': 1,
#   '动作': 1,
#   '剧情': 1,
#   '灾难': 1,
#   '奇幻': 1,
#   '惊悚': 1,
#   '迪伦·奥布莱恩': 1,
#   '卡雅·斯考达里奥': 1,
#   '托马斯·布罗迪-桑斯特': 1,
#   '吉安卡罗·埃斯波西托': 1,
#   '艾丹·吉伦': 1,
#   '美国': 1,
#   '韦斯·鲍尔': 1,
#   '青春': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   'Linda': 1,
#   '美国': 1,
#   'other_director': 1,
#   '文艺': 1},
#  {'恐怖': 1,
#   '音乐': 1,
#   '田丰': 1,
#   '胡锦': 1,
#   'other_actor': 1,
#   '葛小宝': 1,
#   '欧阳莎菲': 1,
#   '台湾': 1,
#   'other_director': 1,
#   '经典': 1},
#  {'传记': 1,
#   '喜剧': 1,
#   '历史': 1,
#   '马修·贝恩顿': 1,
#   'other_actor': 1,
#   '英国': 1,
#   'other_director': 1,
#   '搞笑': 1},
#  {'动作': 1,
#   '战争': 1,
#   '剧情': 1,
#   '吴其江': 1,
#   '宁宁': 1,
#   '聂远': 1,
#   'other_actor': 1,
#   '刘之冰': 1,
#   '中国大陆': 1,
#   '宁海强': 1,
#   '励志': 1},
#  {'爱情': 1,
#   '动作': 1,
#   '犯罪': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'Jeff London': 1,
#   'other_director': 1,
#   '感人': 1},
#  {'喜剧': 1,
#   '克里斯·奥多德': 1,
#   '理查德·艾欧阿德': 1,
#   'other_actor': 1,
#   '英国': 1,
#   '格雷厄姆·莱恩汉': 1,
#   '搞笑': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '奇幻': 1,
#   '剧情': 1,
#   '克里斯汀·贝尔': 1,
#   '威尔·阿奈特': 1,
#   '乔什·杜哈明': 1,
#   '丹尼·德维托': 1,
#   '阿丽西丝·泽纳': 1,
#   '美国': 1,
#   '马克·斯蒂文·约翰逊': 1,
#   '搞笑': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '玛吉·史密斯': 1,
#   '迈克尔·刚本': 1,
#   '克里斯汀·斯科特·托马斯': 1,
#   '卡米拉·拉瑟福德': 1,
#   '克里夫·欧文': 1,
#   '意大利': 1,
#   '罗伯特·奥特曼': 1,
#   '经典': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '中国大陆': 1,
#   'other_director': 1,
#   '经典': 1,
#   '文艺': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '音乐': 1,
#   '剧情': 1,
#   '方力申': 1,
#   '恬妞': 1,
#   '刘以达': 1,
#   '傅颖': 1,
#   '吴雨霏': 1,
#   '香港': 1,
#   '罗守耀': 1,
#   '青春': 1},
#  {'剧情': 1,
#   '中村雁治郎': 1,
#   '原节子': 1,
#   '司叶子': 1,
#   '新珠三千代': 1,
#   '小林桂树': 1,
#   '日本': 1,
#   '小津安二郎': 1,
#   '经典': 1},
#  {'剧情': 1,
#   '摩根·弗里曼': 1,
#   '艾什莉·贾德': 1,
#   '内森·甘宝': 1,
#   '小哈里·康尼克': 1,
#   '科齐·齐尔斯多夫': 1,
#   '美国': 1,
#   '查尔斯·马丁·史密斯': 1,
#   '励志': 1},
#  {'悬疑': 1, '犯罪': 1, '大卫·苏切': 1, '菲利普·杰克森': 1, '英国': 1, '罗斯·大卫尼斯': 1, '经典': 1},
#  {'传记': 1,
#   'other_actor': 1,
#   '吴维': 1,
#   '朱宁': 1,
#   '中国大陆': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '英国': 1,
#   'Sal Bardo': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'喜剧': 1,
#   '朱丽叶·比诺什': 1,
#   '朗贝尔·维尔森': 1,
#   '卡瑟琳·雅各布': 1,
#   'other_actor': 1,
#   '卡米尔·科坦': 1,
#   '法国': 1,
#   '诺米·萨格雷欧': 1,
#   '女性': 1,
#   '搞笑': 1},
#  {'爱情': 1, '同性': 1, 'other_actor': 1, '香港': 1, 'other_director': 1, '青春': 1},
#  {'犯罪': 1,
#   '悬疑': 1,
#   '惊悚': 1,
#   '恐怖': 1,
#   '杰米·李·柯蒂斯': 1,
#   'other_actor': 1,
#   'Busta Rhymes': 1,
#   '西恩·帕特里克·汤玛斯': 1,
#   '美国': 1,
#   '瑞克·罗森塔尔': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '犯罪': 1,
#   '歌舞': 1,
#   '剧情': 1,
#   '让-保罗·贝尔蒙多': 1,
#   '安娜·卡里娜': 1,
#   'other_actor': 1,
#   '意大利': 1,
#   '让-吕克·戈达尔': 1,
#   '经典': 1,
#   '文艺': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '简廷芮': 1,
#   '台湾': 1,
#   'other_director': 1,
#   '青春': 1,
#   '励志': 1},
#  {'科幻': 1,
#   '冒险': 1,
#   '奇幻': 1,
#   '动作': 1,
#   'other_actor': 1,
#   'Lucas Munk Billing': 1,
#   'Anders W': 1,
#   'Berthelsen': 1,
#   '丹麦': 1,
#   'other_director': 1,
#   '魔幻': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '热拉尔丁·纳卡什': 1,
#   '吉姆·罗斯·斯图尔特': 1,
#   '帕斯卡·德莫隆': 1,
#   '苏菲': 1,
#   '卡达尼': 1,
#   '意大利': 1,
#   'other_director': 1,
#   '女性': 1},
#  {'爱情': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '喜剧': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'Tommy Lee Wallace': 1,
#   '经典': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '???': 1,
#   '韩国': 1,
#   '이세일': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '犯罪': 1,
#   '韩石圭': 1,
#   '文成根': 1,
#   '沈惠珍': 1,
#   '宋康昊': 1,
#   '郑在咏': 1,
#   '韩国': 1,
#   '李沧东': 1,
#   '黑帮': 1},
#  {'剧情': 1,
#   '法尔汉·阿赫塔尔': 1,
#   '康柯纳·森·沙尔玛': 1,
#   '里希·卡普尔': 1,
#   '印度': 1,
#   '卓娅·阿赫塔尔': 1,
#   '励志': 1,
#   '文艺': 1},
#  {'科幻': 1,
#   '动作': 1,
#   '刘萌萌': 1,
#   '李宁': 1,
#   'other_actor': 1,
#   '张炜迅': 1,
#   '中国大陆': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'爱情': 1,
#   '战争': 1,
#   '剧情': 1,
#   '费雯·丽': 1,
#   '罗伯特·泰勒': 1,
#   'other_actor': 1,
#   '弗吉尼亚·菲尔德': 1,
#   '美国': 1,
#   '詹姆斯·惠尔': 1,
#   '感人': 1,
#   '经典': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '悬疑': 1,
#   '音乐': 1,
#   'other_actor': 1,
#   '中国大陆': 1,
#   'other_director': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'科幻': 1,
#   '奇幻': 1,
#   '动作': 1,
#   'other_actor': 1,
#   '艾伦·欧朋海默': 1,
#   '英国': 1,
#   'other_director': 1,
#   '魔幻': 1,
#   '经典': 1},
#  {'爱情': 1, '剧情': 1, '阮玲玉': 1, '金焰': 1, '陈燕燕': 1, '中国大陆': 1, '卜万苍': 1, '女性': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   'Onofrio': 1,
#   '英国': 1,
#   'other_director': 1,
#   '文艺': 1},
#  {'犯罪': 1,
#   '爱情': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '战争': 1,
#   '惊悚': 1,
#   '哈维尔·巴登': 1,
#   '胡安·迭戈·博托': 1,
#   '劳拉·莫兰特': 1,
#   '埃尔薇拉·明戈斯': 1,
#   '西班牙': 1,
#   'other_director': 1,
#   '经典': 1},
#  {'同性': 1,
#   '剧情': 1,
#   '海蒂·布雷斯': 1,
#   '安吉丽娜·朱莉': 1,
#   '珍妮·刘易斯': 1,
#   'other_actor': 1,
#   '彼得·费辛利': 1,
#   '美国': 1,
#   '安妮特·海伍德-卡特': 1,
#   '青春': 1,
#   '女性': 1},
#  {'科幻': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '奇幻': 1,
#   '唐纳德·普利森斯': 1,
#   '黄自强': 1,
#   '丽萨·布伦特': 1,
#   '詹姆森·帕克': 1,
#   '丹尼斯·邓恩': 1,
#   '美国': 1,
#   '约翰·卡朋特': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '丹麦': 1,
#   '鲁卡斯·穆迪森': 1,
#   '青春': 1,
#   '女性': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '法国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'歌舞': 1,
#   '爱情': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   'Toni Iera Rakkaen': 1,
#   '泰国': 1,
#   '蒙松': 1,
#   '青春': 1,
#   '励志': 1},
#  {'犯罪': 1,
#   '科幻': 1,
#   '动作': 1,
#   'other_actor': 1,
#   'Brien': 1,
#   '美国': 1,
#   'other_director': 1,
#   '文艺': 1},
#  {'剧情': 1,
#   'other_actor': 1,
#   '有村架純': 1,
#   '山中崇': 1,
#   '宇野祥平': 1,
#   '日本': 1,
#   'other_director': 1,
#   '女性': 1},
#  {'犯罪': 1,
#   '动作': 1,
#   '惊悚': 1,
#   '剧情': 1,
#   '谢霆锋': 1,
#   '伍佰': 1,
#   '卢巧音': 1,
#   'other_actor': 1,
#   '黄秋生': 1,
#   '香港': 1,
#   '徐克': 1,
#   '黑帮': 1},
#  {'歌舞': 1,
#   '音乐': 1,
#   '犯罪': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '铃木亮平': 1,
#   '佐藤隆太': 1,
#   '大东骏介': 1,
#   '石田卓也': 1,
#   '市川由衣': 1,
#   '日本': 1,
#   '园子温': 1,
#   '黑帮': 1},
#  {'恐怖': 1, '徐少强': 1, '雪梨': 1, '香港': 1, '唐伟成': 1, '魔幻': 1},
#  {'爱情': 1,
#   '冒险': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '杰尼斯·纽沃纳': 1,
#   '科奈莉亚·弗洛波伊斯': 1,
#   '德国': 1,
#   '卡蒂娅·冯·加尼尔': 1,
#   '青春': 1},
#  {'动作': 1,
#   '富司纯子': 1,
#   '金子信雄': 1,
#   '三上真一郎': 1,
#   'other_actor': 1,
#   '日本': 1,
#   '山下耕作': 1,
#   '黑帮': 1},
#  {'传记': 1,
#   '剧情': 1,
#   '马丁·兰道': 1,
#   '杰夫·布里吉斯': 1,
#   '琼·艾伦': 1,
#   '美国': 1,
#   '弗朗西斯·福特·科波拉': 1,
#   '经典': 1,
#   '励志': 1},
#  {'传记': 1,
#   '情色': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '山本太郎': 1,
#   '李丹': 1,
#   '黄奕': 1,
#   '日本': 1,
#   'other_director': 1,
#   '黑帮': 1},
#  {'爱情': 1,
#   '科幻': 1,
#   '喜剧': 1,
#   '冒险': 1,
#   '动作': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '武侠': 1,
#   '李连杰': 1,
#   '成龙': 1,
#   '刘亦菲': 1,
#   '李冰冰': 1,
#   '迈克尔·安格拉诺': 1,
#   '香港': 1,
#   '罗伯·明可夫': 1,
#   '魔幻': 1},
#  {'悬疑': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '恐怖': 1,
#   '惊悚': 1,
#   '梅根·福克斯': 1,
#   '阿曼达·塞弗里德': 1,
#   '约翰尼·西蒙斯': 1,
#   '亚当·布罗迪': 1,
#   '美国': 1,
#   '卡瑞恩·库萨马': 1,
#   '青春': 1},
#  {'战争': 1,
#   '剧情': 1,
#   '吕良伟': 1,
#   '韦力': 1,
#   '蒋婧': 1,
#   'other_actor': 1,
#   '香港': 1,
#   'other_director': 1,
#   '经典': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '古天乐': 1,
#   '郭采洁': 1,
#   '吴莫愁': 1,
#   '中国大陆': 1,
#   '韦正': 1,
#   '张荣吉': 1,
#   '搞笑': 1},
#  {'剧情': 1, 'other_actor': 1, '法国': 1, 'other_director': 1, '文艺': 1},
#  {'冒险': 1,
#   '喜剧': 1,
#   '奇幻': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'Matt Vancil': 1,
#   'other_director': 1,
#   '魔幻': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '伊藤淳史': 1,
#   '小出惠介': 1,
#   '长泽雅美': 1,
#   '木村文乃': 1,
#   '川口春奈': 1,
#   '日本': 1,
#   '内村光良': 1,
#   '青春': 1,
#   '励志': 1},
#  {'喜剧': 1,
#   '剧情': 1,
#   '凯瑟琳·基纳': 1,
#   '奥利弗·普莱特': 1,
#   '萨拉·斯蒂尔': 1,
#   '阿曼达·皮特': 1,
#   '丽贝卡·豪尔': 1,
#   '美国': 1,
#   '妮可·哈罗芬瑟': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '战争': 1,
#   '剧情': 1,
#   '汉娜·许古拉': 1,
#   '克劳斯·洛维奇': 1,
#   '伊凡·德斯尼': 1,
#   'other_actor': 1,
#   '高夫莱德·约翰': 1,
#   '德国': 1,
#   '赖纳·维尔纳·法斯宾德': 1,
#   '经典': 1,
#   '女性': 1},
#  {'犯罪': 1,
#   '动作': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '金来沅': 1,
#   '姜信日': 1,
#   '韩国': 1,
#   '崔真源': 1,
#   '励志': 1,
#   '黑帮': 1},
#  {'动作': 1,
#   '悬疑': 1,
#   '剧情': 1,
#   '徐锦江': 1,
#   '陈德容': 1,
#   '谷洋': 1,
#   '叶青青': 1,
#   '中国大陆': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'剧情': 1,
#   '劳米·拉佩斯': 1,
#   '奥拉·拉佩斯': 1,
#   'other_actor': 1,
#   '瑞典': 1,
#   'other_director': 1,
#   '女性': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '麦可拉·沃金丝': 1,
#   '美国': 1,
#   '蒂姆·克里克曼': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '情色': 1,
#   '剧情': 1,
#   '成贤娥': 1,
#   '刘智泰': 1,
#   '吴达洙': 1,
#   '法国': 1,
#   '洪尚秀': 1,
#   '文艺': 1},
#  {'爱情': 1, '喜剧': 1, 'other_actor': 1, '泰国': 1, 'Poj Arnon': 1, '搞笑': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '熊黛林': 1,
#   '立威廉': 1,
#   '何炅': 1,
#   'other_actor': 1,
#   '黄宗泽': 1,
#   '香港': 1,
#   '马伟豪': 1,
#   '搞笑': 1},
#  {'剧情': 1, '安妮·班克罗夫特': 1, '茜茜·斯派塞克': 1, '美国': 1, '汤姆·摩尔': 1, '女性': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '剧情': 1,
#   '丹尼尔·布鲁尔': 1,
#   '奥古斯特·迪赫': 1,
#   '安娜·玛丽亚·穆埃': 1,
#   '托尔·林德哈特': 1,
#   '德国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '柯宇纶': 1,
#   'other_actor': 1,
#   '黄远': 1,
#   '唐治平': 1,
#   '台湾': 1,
#   'other_director': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '歌舞': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '施坦·马洛萨': 1,
#   '杰奎琳·费南德斯': 1,
#   '达山·库马尔': 1,
#   'other_actor': 1,
#   '印度': 1,
#   '克里希纳·D·K': 1,
#   'other_director': 1,
#   '搞笑': 1},
#  {'喜剧': 1,
#   '杰瑞·刘易斯': 1,
#   'other_actor': 1,
#   '凯瑟琳·弗里曼': 1,
#   '乔治·拉夫特': 1,
#   '美国': 1,
#   'other_director': 1,
#   '经典': 1},
#  {'喜剧': 1, 'other_actor': 1, '美国': 1, 'other_director': 1, '文艺': 1},
#  {'剧情': 1,
#   '吴奇隆': 1,
#   '左小青': 1,
#   '叶童': 1,
#   '范伟': 1,
#   '午马': 1,
#   '香港': 1,
#   '张之亮': 1,
#   '青春': 1,
#   '文艺': 1},
#  {'犯罪': 1,
#   '爱情': 1,
#   '剧情': 1,
#   '奇幻': 1,
#   '惊悚': 1,
#   'other_actor': 1,
#   '英国': 1,
#   'other_director': 1,
#   '魔幻': 1},
#  {'爱情': 1,
#   '同性': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   '苏查拉·玛娜英': 1,
#   '素帕娜·吉塔勒拉': 1,
#   'other_actor': 1,
#   '泰国': 1,
#   'other_director': 1,
#   '感人': 1,
#   '青春': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '战争': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '泰国': 1,
#   'Mr': 1,
#   'other_director': 1,
#   '青春': 1,
#   '励志': 1},
#  {'同性': 1, '剧情': 1, 'other_actor': 1, '法国': 1, 'other_director': 1, '青春': 1},
#  {'爱情': 1,
#   '犯罪': 1,
#   '情色': 1,
#   '剧情': 1,
#   '秋吉久美子': 1,
#   '津川雅彦': 1,
#   '池部良': 1,
#   '岸部一德': 1,
#   '日本': 1,
#   '根岸吉太郎': 1,
#   '经典': 1},
#  {'惊悚': 1, '剧情': 1, 'other_actor': 1, '中国大陆': 1, 'other_director': 1, '魔幻': 1},
#  {'爱情': 1,
#   '喜剧': 1,
#   '情色': 1,
#   '菲比·凯茨': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1},
#  {'音乐': 1, '剧情': 1, 'other_actor': 1, '二阶堂富美': 1, '日本': 1, '山下敦弘': 1, '励志': 1},
#  {'剧情': 1, '蒂莫西·柴勒梅德': 1, '美国': 1, 'other_director': 1, '青春': 1},
#  {'爱情': 1,
#   '剧情': 1,
#   '赵薇': 1,
#   '姜文': 1,
#   'other_actor': 1,
#   '张元': 1,
#   '中国大陆': 1,
#   '文艺': 1},
#  {'爱情': 1,
#   '历史': 1,
#   '传记': 1,
#   '许鞍华': 1,
#   'other_actor': 1,
#   '汤唯': 1,
#   '冯绍峰': 1,
#   '香港': 1,
#   'other_director': 1,
#   '女性': 1,
#   '文艺': 1},
#  {'爱情': 1, '剧情': 1, 'other_actor': 1, '美国': 1, '金·维多': 1, '经典': 1},
#  {'爱情': 1,
#   '犯罪': 1,
#   '冒险': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '美国': 1,
#   '凯瑞·福永': 1,
#   '青春': 1,
#   '黑帮': 1},
#  {'剧情': 1, '张智霖': 1, '香港': 1, 'other_director': 1, '文艺': 1},
#  {'爱情': 1,
#   '动作': 1,
#   '剧情': 1,
#   '何润东': 1,
#   '黄子韬': 1,
#   '古力娜扎': 1,
#   '王学圻': 1,
#   '秋瓷炫': 1,
#   'other_actor': 1,
#   '波莱特·杜博斯特': 1,
#   '米拉·帕雷利': 1,
#   '马塞尔·达里奥': 1,
#   '中国大陆': 1,
#   '高希希': 1,
#   '经典': 1,
#   '黑帮': 1},
#  {'同性': 1,
#   '喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'other_director': 1,
#   '搞笑': 1},
#  {'犯罪': 1,
#   '喜剧': 1,
#   '动作': 1,
#   '关之琳': 1,
#   '万梓良': 1,
#   '郑浩南': 1,
#   '于芷蔚': 1,
#   '成奎安': 1,
#   '香港': 1,
#   'other_director': 1,
#   '黑帮': 1},
#  ...]

# %%
movie_dict_list[0]
# Out:
# {'喜剧': 1,
#  '剧情': 1,
#  'other_actor': 1,
#  '美国': 1,
#  'other_director': 1,
#  '青春': 1,
#  '文艺': 1}

# %% [markdown]
# ## 使用DictVectorizer进行向量化，做one-hot编码

# %%
v = DictVectorizer()
X = v.fit_transform(movie_dict_list)
X.shape
# Out:
# (23034, 16952)

# %%
movie_dict_list[0:1]
# Out:
# [{'喜剧': 1,
#   '剧情': 1,
#   'other_actor': 1,
#   '美国': 1,
#   'other_director': 1,
#   '青春': 1,
#   '文艺': 1}]

# %% [markdown]
# ## 计算cosine相似度

# %%
item_similarity = pairwise_distances(X, metric='cosine')

# %% [markdown]
# ## 测试代码，查看相似度的准确性

# %%
compare_index = 3
index = 0
_max_index = 0
_max = 1
for i in item_similarity[compare_index]:
    if i < _max and i != 0:
        _max = 1
        _max_index = index
    index = index + 1

# %%
_max_index, _max
# Out:
# (23026, 1)

# %%
index_of_sim = _max_index

# %%
df.iloc[index_of_sim]
# Out:
# actors      Ray Liotta|Linda Boston|Ele Bardha|Ron Causey|...
# director                                         Chris Fisher
# name                                                街头之王2：汽车城
# rat                                                       4.8
# region                                                     美国
# traits                                                     黑帮
# type                                              犯罪|动作|悬疑|剧情
# movie_id                                                23027
# Name: 23026, dtype: object

# %%
movie_dict_list[index_of_sim]
# Out:
# {'犯罪': 1,
#  '动作': 1,
#  '悬疑': 1,
#  '剧情': 1,
#  'Ray Liotta': 1,
#  'other_actor': 1,
#  '美国': 1,
#  'other_director': 1,
#  '黑帮': 1}

# %%
df_106 = pd.DataFrame(data=X.todense()[index_of_sim], columns=v.feature_names_)
df_0 = pd.DataFrame(data=X.todense()[compare_index], columns=v.feature_names_)
df_diff = pd.concat([df_0, df_106], axis=0, ignore_index=True)
df_diff = df_diff.T

# %%
df_diff[(df_diff[0] != 0) | (df_diff[1] != 0)]
# Out:
#                   0    1
# Ray Liotta      0.0  1.0
# other_actor     0.0  1.0
# other_director  0.0  1.0
# 剧情              0.0  1.0
# 动作              0.0  1.0
# 安吉拉·兰斯伯瑞        1.0  0.0
# 悬疑              1.0  1.0
# 惊悚              1.0  0.0
# 托尼·柯蒂斯          1.0  0.0
# 杰拉丁·卓别林         1.0  0.0
# 爱德华·福克斯         1.0  0.0
# 犯罪              1.0  1.0
# 盖伊·汉弥尔顿         1.0  0.0
# 经典              1.0  0.0
# 罗克·赫德森          1.0  0.0
# 美国              0.0  1.0
# 英国              1.0  0.0
# 黑帮              0.0  1.0

# %%
df_sim = pd.DataFrame(data=item_similarity)
item_similarity.shape[0]
# Out:
# 23034

# %% [markdown]
# ## 最相似的前200个电影

# %%
df_sim.nsmallest(200, 6600)[6600].to_dict().items()
# Out:
# dict_items([(6600, 0.0), (18013, 0.49748109237039395), (21127, 0.5165062215847719), (1813, 0.5232687053772038), (19634, 0.5232687053772038), (9883, 0.5441576941614482), (10743, 0.5441576941614482), (16840, 0.5441576941614482), (18452, 0.5441576941614482), (22587, 0.5454545454545454), (2471, 0.5648058601107554), (13764, 0.5648058601107554), (19039, 0.5648058601107554), (19151, 0.5648058601107554), (2271, 0.5735985672887791), (4030, 0.5735985672887791), (5631, 0.5735985672887791), (8681, 0.5735985672887791), (15140, 0.5735985672887791), (21518, 0.5735985672887791), (21817, 0.5735985672887791), (2344, 0.5818789949964546), (3049, 0.5818789949964546), (5709, 0.5818789949964546), (7373, 0.5818789949964546), (10567, 0.5818789949964546), (11728, 0.5818789949964546), (14316, 0.5818789949964546), (17606, 0.5818789949964546), (19025, 0.5818789949964546), (2629, 0.5954800825220548), (3105, 0.5954800825220548), (3852, 0.5970885179873099), (6497, 0.5970885179873099), (8886, 0.5970885179873099), (11280, 0.5970885179873099), (13157, 0.5970885179873099), (2744, 0.5979848738963152), (3339, 0.5979848738963152), (4312, 0.5979848738963152), (4891, 0.5979848738963152), (5658, 0.5979848738963152), (6673, 0.5979848738963152), (7367, 0.5979848738963152), (11388, 0.5979848738963152), (11810, 0.5979848738963152), (13160, 0.5979848738963152), (13993, 0.5979848738963152), (17883, 0.5979848738963152), (19920, 0.5979848738963152), (20381, 0.5979848738963152), (22464, 0.5979848738963152), (1878, 0.6107505279192385), (3582, 0.6107505279192385), (15507, 0.6107505279192385), (1090, 0.6186149643017631), (2366, 0.6186149643017631), (2427, 0.6186149643017631), (3679, 0.6186149643017631), (4372, 0.6186149643017631), (4455, 0.6186149643017631), (4469, 0.6186149643017631), (5126, 0.6186149643017631), (6385, 0.6186149643017631), (7482, 0.6186149643017631), (9074, 0.6186149643017631), (10447, 0.6186149643017631), (12476, 0.6186149643017631), (12934, 0.6186149643017631), (13164, 0.6186149643017631), (13239, 0.6186149643017631), (13913, 0.6186149643017631), (14406, 0.6186149643017631), (14631, 0.6186149643017631), (14815, 0.6186149643017631), (15901, 0.6186149643017631), (16467, 0.6186149643017631), (16483, 0.6186149643017631), (17485, 0.6186149643017631), (19879, 0.6186149643017631), (20581, 0.6186149643017631), (21490, 0.6186149643017631), (21948, 0.6186149643017631), (22670, 0.6186149643017631), (4872, 0.6307255270620018), (5829, 0.6307255270620018), (6705, 0.6307255270620018), (7474, 0.6307255270620018), (8208, 0.6307255270620018), (9097, 0.6307255270620018), (10287, 0.6307255270620018), (12961, 0.6307255270620018), (15070, 0.6307255270620018), (17243, 0.6307255270620018), (21621, 0.6307255270620018), (22021, 0.6307255270620018), (22425, 0.6307255270620018), (163, 0.6343637879364347), (223, 0.6363636363636364), (322, 0.6363636363636364), (411, 0.6363636363636364), (1374, 0.6363636363636364), (1571, 0.6363636363636364), (2699, 0.6363636363636364), (2889, 0.6363636363636364), (3144, 0.6363636363636364), (3160, 0.6363636363636364), (3369, 0.6363636363636364), (3651, 0.6363636363636364), (3677, 0.6363636363636364), (3897, 0.6363636363636364), (4555, 0.6363636363636364), (5415, 0.6363636363636364), (6020, 0.6363636363636364), (6355, 0.6363636363636364), (6518, 0.6363636363636364), (6761, 0.6363636363636364), (8174, 0.6363636363636364), (8396, 0.6363636363636364), (9055, 0.6363636363636364), (9059, 0.6363636363636364), (9975, 0.6363636363636364), (10077, 0.6363636363636364), (10191, 0.6363636363636364), (10762, 0.6363636363636364), (10938, 0.6363636363636364), (11156, 0.6363636363636364), (11933, 0.6363636363636364), (12435, 0.6363636363636364), (12773, 0.6363636363636364), (12838, 0.6363636363636364), (13646, 0.6363636363636364), (13745, 0.6363636363636364), (13812, 0.6363636363636364), (14087, 0.6363636363636364), (14267, 0.6363636363636364), (14920, 0.6363636363636364), (15569, 0.6363636363636364), (15701, 0.6363636363636364), (15786, 0.6363636363636364), (15898, 0.6363 ...
