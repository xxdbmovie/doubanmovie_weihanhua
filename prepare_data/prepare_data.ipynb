# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from functools import reduce
import time

# %%
# movie path
movie_filepath = "../dataset/movie.csv"
# user path
user_filepath = "../dataset/user.csv"

# %%
movies = pd.read_csv(movie_filepath)
movies.shape
# Out:
# (93160, 7)

# %%
movies.head()
# Out:
#    类型                  主演    地区     导演  特色   评分     电影名
# 0  剧情    徐峥|王传君|周一围|谭卓|章宇  中国大陆    文牧野  经典  8.9   我不是药神
# 1  剧情   冯小刚|许晴|张涵予|刘桦|李易峰  中国大陆     管虎  经典  7.8     老炮儿
# 2  剧情  王宝强|刘昊然|肖央|刘承羽|尚语贤  中国大陆    陈思诚  经典  6.7  唐人街探案2
# 3  剧情  任素汐|大力|刘帅良|裴魁山|阿如那  中国大陆  周申|刘露  经典  8.3     驴得水
# 4  剧情   徐峥|王宝强|李曼|李小璐|左小青  中国大陆    叶伟民  经典  7.5    人在囧途

# %%
users = pd.read_csv(user_filepath)

# %%
users.shape
# Out:
# (199813, 6)

# %%
users.head()
# Out:
#    评分     用户名                 评论时间  用户ID    电影名  类型
# 0   2      身似  2018-01-05 15:05:06     1   心雨花露  爱情
# 1   4  有意识的贱民  2018-01-05 15:05:06     3  战争的恐怖  战争
# 2   2    亿万露电  2018-01-05 15:05:06     4  豪勇七蛟龙  战争
# 3   2   Marni  2018-01-05 15:05:06     5   无序之主  犯罪
# 4   4   马西嘻嘻嘻  2018-01-05 15:05:06     6  时装店风波  同性

# %%
# 准备电影数据
def prepare_movie_data(movies):
    names_set = set(movies['电影名'].tolist())  # 全量的电影名

    movies_list = []  # 接受电影信息的字典
    for movie_name in tqdm(names_set):
        movieinfo = movies[movies['电影名'] == movie_name]

        g = lambda x : movieinfo[x].iloc[0]  # 取某个列中的第一个数据
        actors = movieinfo['主演'].tolist()  # 主演的列表
        actors = reduce(lambda x, y: x + '|' + y, list(set(actors)))  # 主演列表去重再使用|进行分割
        types = movieinfo['类型'].tolist()  # 电影类型的列表
        types = reduce(lambda x, y : x + '|' + y, list(set(types)))  # 电影类型列表去重再使用|进行分割
        traits = movieinfo['特色'].tolist()  # 电影特色列表
        traits = reduce(lambda x, y : x + '|' + y, list(set(traits)))  # 特色列表去重再使用|进行分割

        movies_info = {"name": movie_name,
                       "type": types,
                       "actors": actors,
                       "region": g("地区"),
                       "director": g("导演"),
                       "traits": traits,
                       "rat": g("评分")}
        movies_list.append(movies_info)
    movies_df = pd.DataFrame(movies_list)  # 字典转换成DataFrame
    movies_df['movie_id'] = range(1, len(movies_df.index) + 1)  # 添加电影id
    movies_df.to_csv("../dataset/processed_movies.csv", index=False)
    return movies_df

# %%
prepare_movie_data(movies)  # 处理电影数据
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 23034/23034 [02:30<00:00, 152.93it/s]
#                                                   actors  \
# 0      杰夫里·乔 Jeffrey Chyau|姜星 Sung Kang|吴玉 Jade Wu|萨曼...
# 1                                 海瑟·格拉汉姆|杰瑞·奥康奈尔|约翰·考伯特
# 2                  史蒂夫·卡瑞尔|摩根·弗里曼|劳伦·格拉汉姆|约翰尼·西蒙斯|约翰·古德曼
# 3                 安吉拉·兰斯伯瑞|杰拉丁·卓别林|托尼·柯蒂斯|爱德华·福克斯|罗克·赫德森
# 4                                北野武|浅野忠信|大楠道代|夏川结衣|岸部一德
# 5                     马克·韦伯|泽娜·格雷|埃曼纽尔·施莱琪|克里斯·艾略特|珍·斯马特
# 23006               Jay Martin                疾速天使  3.6     美国
# 23007                      罗卓瑶                暴走神探  5.3     香港
# 23008                      屠光启                摩登女性  6.5   中国大陆
# 23009          Shannon Hartman      比尔·伯尔：我为什么这么做？  9.0     美国
# 23010                   查理·卓别林              百货店巡视员  8.1     美国
# 23011            Steve Michaud           阿伦·艾弗森之答案  9.2     美国
# 23012                   艾拉·萨克斯                 爱很怪  7.8     巴西
# 23013                  皮耶·寇拉尼克                  安娜  7.7     法国
# 23014                   艾米·海克林                飞越童真  6.9     美国
# 23015                     强·卡萨              当树枝折断时  5.6     美国
# 23016            Marty Callner   Justin Timberlake  9.4     美国
# 23017                   罗杰·唐纳森               惊爆十三天  7.9     美国
# 23018                  派翠西亚·里根               柠檬大嘴巴  6.8     美国
# 23019                    庭月野議啓               仁光受难记  6.6     日本
# 23020                   吉姆·贾木许                 帕特森  8.0     德国
# 23021                   吉姆·贾木许                神秘列车  8.2     日本
# 23022                 道格拉斯·麦可恩                异形再现  6.6     美国
# 23023             Steve Taylor               第二次机会  7.4     美国
# 23024            Louise Osmond                麦昆与我  8.7     英国
# 23025              Henry Saine                赏金杀手  5.3     美国
# 23026             Chris Fisher           街头之王2：汽车城  4.8     美国
# 23027                奥利维耶·阿萨亚斯           我的爱情遗忘在秋天  7.5     法国
# 23028               Danny Roth               国际交换生  4.5     美国
# 23029                   安妮·弗莱彻               舞出我人生  7.6     美国
# 23030                  大卫·S·瓦德            美国职棒大联盟2  7.3     美国
# 23031                    内德·本森          他和她的孤独情事：他  6.8     美国
# 23032                     柳泽哲也  告白实行委员会：从很久以前就喜欢你了  7.2     日本
# 23033                     増尾昭一                  紅狼  6.7     日本
#
#                   traits                  type  movie_id
# 0                  青春|文艺                 喜剧|剧情         1
# 1                     女性                 爱情|喜剧         2
# 2               魔幻|励志|搞笑           科幻|喜剧|奇幻|剧情         3
# 3                     经典              悬疑|惊悚|犯罪         4
# 4                     经典        音乐|犯罪|动作|剧情|武侠         5
# 5                     青春              爱情|冒险|喜剧         6
# 6                  青春|搞笑              爱情|喜剧|剧情         7
# 7                     文艺                 爱情|剧情         8
# 8                     经典                    冒险         9
# 9                     女性              同性|喜剧|剧情        10
# 10                 青春|文艺           爱情|情色|同性|剧情        11
# 11                    黑帮        犯罪|爱情|动作|剧情|惊悚        12
# 12                    文艺                    悬疑        13
# 13                    青春           犯罪|悬疑|惊悚|剧情        14
# 14                    搞笑              喜剧|音乐|奇幻        15
# 15                    文艺                    剧情        16
# 16                    青春                 爱情|同性        17
# 17     感人|青春|搞笑|励志|文艺|经典              爱情|喜剧|剧情        18
# 18                    女性                 犯罪|剧情        19
# 19                 青春|文艺                 爱情|剧情        20
# 20                    魔幻        科幻|悬疑|剧情|奇幻|惊悚        21
# 21                    搞笑           爱情|冒险|喜剧|奇幻        22
# 22                    青春                    爱情        23
# 23                    女性        犯罪|悬疑|剧情|恐怖|惊悚        24
# 24                    黑帮           犯罪|动作|喜剧|剧情        25
# 25                 魔幻|搞笑        爱情|科幻|喜剧|剧情|奇幻        26
# 26                    经典              科幻|惊悚|奇幻        27
# 27                    青春                 喜剧|剧情        28
# 28                    魔幻     爱情|科幻|剧情|奇幻|恐怖|惊悚        29
# 29                 魔幻|经典        科幻|冒险|动作|剧情|奇幻        30
# ...                  ...                   ...       ...
# 23004                 青春                    剧情     23005
# 23005                 搞笑              恐怖|惊悚|喜剧     23006
# 23006                 魔幻        科幻|冒险|喜剧|动作|剧情     23007
# 23007                 文艺     犯罪|爱情|悬疑|喜剧|动作|剧情     23008
# 23008              经典|女性                 爱情|剧情     23009
# 23009                 搞笑                    喜剧     23010
# 23010                 经典                    喜剧     23011
# 23011                 励志                    传记     23012
# 23012                 文艺              爱情|同性|剧情     23013
# 23013                 女性                    音乐     23014
# 23014                 搞笑                 爱情|喜剧     23015
# 23015                 青春     犯罪|爱情|悬疑|剧情|恐怖|惊悚     23016
# 23016                 经典                    音乐     23017
# 23017                 经典     传记|悬疑|历史|剧情|战争|惊悚     23018
# 23018              青春|励志        歌舞|音乐|爱情|喜剧|剧情     23019
# 23019                 青春                 情色|剧情     23020
# 23020                 文艺                 爱情|剧情     23021
# 23021                 文艺           犯罪|喜剧|音乐|剧情     23022
# 23022                 经典              科幻|恐怖|惊悚     23023
# 23023              经典|励志                 喜剧|剧情     23024
# 23024                 经典                    传记     23025
# 23025                 搞笑  犯罪|科幻|西部|喜剧|冒险|动作|惊悚     23026
# 23026                 黑帮           犯罪|动作|悬疑|剧情     23027
# 23027                 文艺                 爱情|剧情     23028
# 23028              青春|搞笑                 爱情|喜剧     23029
# 23029              青春|励志           爱情|歌舞|音乐|剧情     23030
# 23030                 搞笑                    喜剧     23031
# 23031                 文艺                    爱情     23032
# 23032                 青春                 爱情|剧情     23033
# 23033                 魔幻                 科幻|情色     23034
#
# [23034 rows x 8 columns]

# %%
# 得出每个用户评分的统计数据
def prepare_rating_statistics_data(movies_df, users):
    tqdm.pandas(desc="process_movie_id")
    # 根据电影名，关联得到电影id
    users['movie_id'] = users['电影名'].progress_map(lambda x: movies_df[movies_df['name'] == x].movie_id.iloc[0])
    tqdm.pandas(desc="process_timestamp")
    users['timestamp'] = pd.to_datetime(users['评论时间'], format='%Y-%m-%d %H:%M:%S')
    users['评分'] = users['评分'].astype(float)
    users.rename(columns={"用户ID": "UserId", "movie_id": "MovieId", "评分": "Rating", "timestamp": "Timestamp"}, inplace=True)
    users = users.drop(['用户名', '评论时间', '电影名', '类型'], axis=1)
    list_users_statistics = []
    tqdm.pandas(desc="process_statistics")
    for UserId, users_ele in tqdm(users.groupby(by=['UserId'])):
        users_ele['rmax'] = users_ele['Rating'].max()
        users_ele['rmin'] = users_ele['Rating'].min()
        users_ele['rcount'] = len(users_ele['Rating'].dropna())
        users_ele['rsum'] = users_ele['Rating'].sum()
        users_ele['ravg'] = users_ele['Rating'].mean()
        users_ele['rmedian'] = np.median(np.array(users_ele['Rating']).astype(float))
        list_users_statistics.append(users_ele)
    users_statistics = pd.concat(list_users_statistics, axis=0)
    users_statistics.to_csv("../dataset/processed_users_ratings_statistics.csv", index=False)

# %%
# 读取处理后的电影数据
movies_df = pd.read_csv("../dataset/processed_movies.csv")

# %%
prepare_rating_statistics_data(movies_df, users)
# Out:
# process_movie_id: 100%|███████████████████████████████████████████████████████| 199813/199813 [06:24<00:00, 519.66it/s]
#   0%|                                                                                        | 0/13545 [00:00<?, ?it/s]D:\softwareInstallation\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\softwareInstallation\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# D:\softwareInstallation\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# D:\softwareInstallation\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\softwareInstallation\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\softwareInstallation\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 100%|██████████████████████████████████████████████████████████████████████████| 13545/13545 [1:09:39<00:00,  3.24it/s]
